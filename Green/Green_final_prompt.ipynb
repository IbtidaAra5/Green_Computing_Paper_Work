# %%
# !pip install tiktoken pandas

import tiktoken
import pandas as pd

enc = tiktoken.get_encoding("cl100k_base")

def count_tokens(text):
    return len(enc.encode(text))

# ==== ALL 5 CATEGORIES (5 pairs each) ====
data = {
    "Assignment Writing": [
        {
            "baseline_prompt": """I am doing an assignment for my university Environmental Science course and I need help with a question about energy sources. Please write an explanation of around 200 words comparing renewable and non-renewable energy sources. Explain what each one is, give two examples of each, and discuss their main environmental impact. Please make the explanation clear and understandable for a student and make sure that all of the important points are properly explained.""",
            "baseline_output": """Renewable and Non-Renewable Energy Sources
Energy sources can be divided into two main types: renewable and non-renewable. Renewable energy comes from natural resources that are continuously replenished and can be used repeatedly without being permanently depleted. Examples include solar energy, which comes from sunlight, and wind energy, which uses moving air to generate electricity. Renewable energy generally has a lower environmental impact because it produces little or no greenhouse gas emissions during operation. However, renewable energy projects can still affect ecosystems, for example, through land use, habitat disturbance, and changes to landscapes.
Non-renewable energy comes from resources that exist in limited amounts and take millions of years to form, so they cannot be replaced quickly once they are used. Examples include coal and petroleum (oil). These fuels are widely used for electricity, transportation, and industry, but their environmental impacts are significant. Burning coal and oil releases carbon dioxide and other pollutants, contributing to climate change, air pollution, and acid rain. Extracting these fuels can also damage land and water resources through mining, drilling, and oil spills.
Overall, renewable energy is generally more sustainable and environmentally friendly, while non-renewable energy causes greater pollution and resource depletion. Transitioning toward renewable sources can help reduce environmental damage and greenhouse gas emissions.""",
            "optimized_prompt": """For an introductory Environmental Science assignment, compare renewable and non-renewable energy sources in about 200 words. Address the following:
Define renewable and non-renewable energy.
Provide two examples of each type.
Outline the primary environmental impact of each source.""",
            "optimized_output": """Renewable and Non-Renewable Energy Sources
Energy sources are generally classified as renewable or non-renewable based on how quickly they can be naturally replaced. Renewable energy comes from natural resources that are continuously replenished and can be used repeatedly. Examples include solar energy, which uses sunlight to produce electricity or heat, and wind energy, which uses moving air to generate electricity. Renewable energy usually has a lower environmental impact than fossil fuels because it produces little or no greenhouse gas emissions during operation. However, renewable energy projects can still affect the environment through land use, habitat disturbance, and changes to natural landscapes.
Non-renewable energy comes from resources that are finite and take extremely long periods, often millions of years, to form. Once consumed, they cannot be replaced within a human lifetime. Coal and petroleum (oil) are two common examples. The main environmental impact of using these fuels is the release of greenhouse gases, particularly carbon dioxide, which contributes to climate change. Burning coal and oil also produces air pollutants that can harm human health and ecosystems. In addition, mining, drilling, and oil extraction can cause habitat destruction, soil degradation, and water pollution.
Overall, renewable energy is generally more sustainable and has fewer environmental impacts, while non-renewable energy contributes significantly to pollution, climate change, and resource depletion.
Pair 1.2"""
        },
        {
            "baseline_prompt": """I am working on an assignment for my university Data Science class where I have to draft an essay outline about supervised, unsupervised, and reinforcement learning. Can you please write a clear essay outline for me? Make sure to include an introduction section, main body section for each of the three paradigms, and a conclusion section with all relevant details so I can use it to write my paper.""",
            "baseline_output": """Essay Outline: Supervised, Unsupervised, and Reinforcement Learning
1. Introduction
Background: Introduce machine learning as a major area of Artificial Intelligence and Data Science that enables computers to learn patterns from data.
Purpose: Explain that machine learning contains several learning paradigms designed for different types of problems.
Thesis statement: This essay will examine supervised, unsupervised, and reinforcement learning by comparing their learning processes, training data, applications, advantages, and limitations.
Briefly introduce the three paradigms.
2. Supervised Learning
2.1 Definition
Explain that supervised learning trains models using labelled datasets containing inputs and known target outputs.
2.2 How It Works
Training data is provided to the model.
The model learns relationships between inputs and outputs.
The trained model makes predictions on new, unseen data.
2.3 Common Tasks
Classification: Predicting categories, such as spam or non-spam emails.
Regression: Predicting numerical values, such as house prices.
2.4 Advantages and Limitations
Advantages: High predictive accuracy with suitable labelled data; performance can be evaluated using known targets.
Limitations: Requires large amounts of labelled data; data labelling can be expensive and time-consuming.
3. Unsupervised Learning
3.1 Definition
Explain that unsupervised learning works with unlabelled data and discovers hidden patterns or structures.
3.2 How It Works
The algorithm analyzes the available data without predefined target outputs.
It identifies similarities, groups, relationships, or unusual observations.
3.3 Common Applications
Customer segmentation using clustering.
Anomaly detection in financial transactions.
Dimensionality reduction for complex datasets.
3.4 Advantages and Limitations
Advantages: Does not require labelled data; useful for discovering previously unknown patterns.
Limitations: Results can be difficult to interpret; evaluating the quality of discovered patterns can be challenging.
4. Reinforcement Learning
4.1 Definition
Explain reinforcement learning as a paradigm in which an agent learns through interaction with an environment.
4.2 How It Works
The agent observes the current state.
It takes an action.
The environment provides a reward or penalty.
The agent learns a strategy, or policy, that aims to maximize cumulative reward over time.
4.3 Real-World Applications
Robotics and autonomous systems.
Game-playing systems.
Resource allocation and recommendation optimization.
4.4 Advantages and Limitations
Advantages: Can learn effective strategies through experience; does not always require labelled training examples.
Limitations: Training can require substantial time and computational resources; poorly designed reward functions can produce undesirable behaviour.
5. Comparison of the Three Paradigms
Supervised: Learns from labelled input-output examples.
Unsupervised: Finds patterns in unlabelled data.
Reinforcement: Learns through actions, feedback, and rewards.
Compare their training processes, data requirements, objectives, and typical applications.
Discuss how the choice of paradigm depends on the problem and available data.
6. Conclusion
Summarize the key characteristics of all three learning paradigms.
Emphasize that each approach is appropriate for different types of Data Science problems.
Reinforce the importance of selecting a learning paradigm based on the available data, desired outcome, and problem requirements.
Conclude by noting that understanding these paradigms is essential for applying machine learning effectively in real-world situations.""",
            "optimized_prompt": """For a university Data Science assignment, create a structured essay outline on Machine Learning Paradigms (Supervised, Unsupervised, Reinforcement Learning). Ensure the output includes:
Introduction section with thesis statement.
Three main body sections with key sub-topics per paradigm.
Brief conclusion section summary.""",
            "optimized_output": """Essay Outline: Machine Learning Paradigms
1. Introduction
Background: Define Machine Learning (ML) as a branch of Artificial Intelligence that enables systems to learn patterns from data and improve performance without being explicitly programmed for every task.
Three paradigms: Introduce supervised, unsupervised, and reinforcement learning as major approaches to machine learning.
Importance: Explain their relevance to areas such as prediction, pattern discovery, automation, and decision-making.
Thesis Statement: This essay examines supervised, unsupervised, and reinforcement learning by comparing their learning processes, data requirements, applications, advantages, and limitations.
2. Supervised Learning
Key Sub-topics
Definition: Learning from labelled input-output data.
How it works: Model learns the relationship between features and known target variables.
Main tasks: Classification and regression.
Applications: Spam detection, medical diagnosis, and house-price prediction.
Advantages: Effective for prediction when sufficient labelled data is available.
Limitations: Requires labelled training data, which can be costly and time-consuming to obtain.
3. Unsupervised Learning
Key Sub-topics
Definition: Learning from unlabelled data without predefined target outputs.
How it works: Identifies patterns, relationships, or structures within datasets.
Main techniques: Clustering and dimensionality reduction.
Applications: Customer segmentation, anomaly detection, and market analysis.
Advantages: Can discover previously unknown patterns without labelled data.
Limitations: Results can be difficult to interpret and evaluate.
4. Reinforcement Learning
Key Sub-topics
Definition: Learning through interaction between an agent and its environment.
How it works: The agent takes actions and receives rewards or penalties.
Key concepts: Agent, environment, state, action, reward, and policy.
Applications: Robotics, autonomous systems, and game playing.
Advantages: Suitable for sequential decision-making and adaptive behaviour.
Limitations: Training can require substantial time, data, and computational resources.
5. Conclusion
Summarize the fundamental differences among the three paradigms.
Supervised learning predicts known outcomes, unsupervised learning discovers hidden patterns, and reinforcement learning learns optimal actions through feedback.
Conclude that selecting the appropriate paradigm depends on the nature of the problem, available data, and desired outcome.
Pair 1.3"""
        },
        {
            "baseline_prompt": """I need to complete a comparison table for my university Software Engineering assignment comparing monolithic and microservices architectures. Can you create a table for me that compares them based on key factors like scalability, deployment complexity, fault isolation, and development speed? Make sure it is formatted clearly with explanations for each point so I can copy it into my assignment report.""",
            "baseline_output": """Below is a clear comparison table suitable for a university Software Engineering report.
Summary: Monolithic architecture generally offers simplicity and easier deployment, while microservices provide greater scalability, fault isolation, and flexibility at the cost of increased operational complexity.""",
            "optimized_prompt": """For a university Software Engineering assignment, generate a Markdown comparison table between Monolithic and Microservices architectures. Include:
Comparison across 4 key criteria (Scalability, Deployment Complexity, Fault Isolation, Development Speed).
Concise comparative descriptions (max 15 words per table cell).""",
            "optimized_output": """Pair 1.4"""
        },
        {
            "baseline_prompt": """I am writing a case study analysis for my university Macroeconomics course about how tech companies respond to rising inflation rates. Could you please write a 200-word analysis paragraph summarizing the key challenge, explaining how inflation impacts operational costs, and proposing two strategic business solutions? Make sure it reads academically for submission.""",
            "baseline_output": """Case Study Analysis: Technology Companies and Rising Inflation
Rising inflation presents a significant challenge for technology companies because it increases operating costs while creating uncertainty about consumer demand and investment decisions. A key challenge is maintaining profitability without reducing competitiveness in a market where customers may become more price-sensitive. Inflation can increase operational costs through higher employee wages, office rents, cloud-computing services, energy prices, hardware components, transportation, and other business inputs. Technology firms may also face increased financing costs when central banks raise interest rates to control inflation, making investment in research, expansion, and infrastructure more expensive. If companies pass all cost increases to customers through higher prices, they risk losing demand or market share.
Two strategic solutions can help firms manage these pressures. First, companies can implement cost-efficiency measures, such as automating routine processes, optimizing cloud-resource usage, renegotiating supplier contracts, and prioritizing high-return investments. These measures can reduce unnecessary expenditure while maintaining product quality. Second, firms can adopt a strategic pricing and product approach, including carefully targeted price adjustments, tiered subscription plans, and greater emphasis on products or services with strong customer value. This allows companies to recover some increased costs without applying uniform price increases across all customers.
Overall, successful inflation management requires balancing cost control, pricing decisions, innovation, and long-term competitiveness.""",
            "optimized_prompt": """For a Macroeconomics case study assignment, write a 200-word corporate analysis paragraph addressing:
Statement of the primary inflation challenge facing tech firms.
Explanation of operational cost impacts.
Proposal of two strategic economic mitigation steps.""",
            "optimized_output": """Corporate Analysis: Inflation and Technology Firms
Rising inflation creates a significant challenge for technology firms by increasing operating expenses while potentially weakening consumer demand and profit margins. The primary challenge is maintaining profitability and competitiveness when the costs of labour, technology infrastructure, and business inputs are rising. Inflation affects operational costs through higher employee wages, office rents, energy prices, cloud-computing services, hardware, and supplier charges. In addition, central banks may respond to persistent inflation by raising interest rates, increasing borrowing costs for firms and making investment in research, expansion, and new infrastructure more expensive. If technology companies transfer these higher costs directly to customers through price increases, they may experience reduced demand or loss of market share.
Two strategic economic mitigation measures can help firms respond effectively. First, companies should strengthen cost efficiency by automating routine activities, optimizing cloud and energy consumption, renegotiating supplier contracts, and prioritizing investments with strong expected returns. Second, firms should adopt flexible pricing strategies, such as carefully targeted price increases, tiered subscription models, or differentiated product packages. These approaches can help recover higher costs while preserving affordability for price-sensitive customers. Overall, technology firms should combine disciplined cost management with carefully designed pricing strategies. This balanced approach can protect profit margins while maintaining customer value and supporting long-term competitiveness during periods of elevated inflation.
Pair 1.5"""
        },
        {
            "baseline_prompt": """I am working on an assignment for my university Research Methods course where I need to argue why qualitative research methods are essential for studying human behavior. Please write a compelling academic paragraph of about 150 words that presents a strong claim, supports it with logical reasoning, and addresses a common counter-argument about quantitative objectivity.""",
            "baseline_output": """Importance of Qualitative Research in Studying Human Behavior
Qualitative research methods are essential for studying human behavior because they provide insight into the meanings, experiences, motivations, and social contexts that cannot always be adequately represented through numerical data. Human behavior is shaped by personal beliefs, cultural backgrounds, relationships, and situational factors; therefore, understanding these influences often requires methods such as interviews, observations, and focus groups that allow participants to describe their experiences in their own words. Although quantitative research is often considered more objective because it relies on standardized measurements and statistical analysis, numerical data alone may overlook the reasons behind people's actions or the complexity of their lived experiences. Critics may argue that qualitative research is subjective and therefore less reliable. However, researchers can strengthen qualitative credibility through systematic data collection, transparent analytical procedures, participant validation, and triangulation. Rather than competing with quantitative approaches, qualitative research complements them by explaining the meanings and processes underlying measurable patterns. Consequently, qualitative methods are indispensable for developing a deeper and more context-sensitive understanding of human behavior.""",
            "optimized_prompt": """For a university Research Methods assignment, write a 150-word argumentative paragraph favoring qualitative research for human behavior studies. Include:
A clear central topic claim.
Supporting logical reasoning and justification.
A concise counter-argument rebuttal regarding quantitative objectivity.""",
            "optimized_output": """Qualitative research is essential for studying human behavior because it reveals the meanings, experiences, motivations, and social contexts that numerical measurements alone may not capture. Human behavior is complex and influenced by factors such as culture, personal beliefs, relationships, and individual experiences; therefore, methods such as interviews, observations, and focus groups can provide detailed insights into why people behave in particular ways. Qualitative approaches also allow researchers to explore unexpected themes and perspectives that may not be identified through predetermined survey questions. Although quantitative research is often regarded as more objective because it uses standardized measurements and statistical analysis, objectivity does not necessarily mean complete understanding. Quantitative methods can identify patterns and relationships but may provide limited insight into the reasons and experiences underlying those patterns. Furthermore, qualitative research can maintain credibility through systematic procedures, transparent analysis, and triangulation. Therefore, qualitative research should be considered an essential approach for understanding human behavior, particularly when the research aims to explore complex experiences and social meanings."""
        },
    ],
    "Exam Preparation": [
        {
            "baseline_prompt": """I have an upcoming exam for my university Database Management Systems course and I need some practice questions to prepare. Can you please generate 5  practice multiple-choice questions for me focusing on SQL normalization (1NF, 2NF, and 3NF)? Please include 4 options for each question, clearly mark the correct answer, and provide a short explanation for each answer so I can study well for my test tomorrow.""",
            "baseline_output": """DBMS Normalization Practice MCQs
1. First Normal Form (1NF)
Which of the following is a requirement of First Normal Form (1NF)?
A. No partial dependencies
 B. No transitive dependencies
 C. Each attribute contains only atomic (single) values
 D. Every non-key attribute depends on the primary key
Correct Answer: C
Explanation: 1NF requires each field to contain a single, indivisible value and does not allow repeating groups or multi-valued attributes.
2. Second Normal Form (2NF)
A relation is in 2NF if it is already in 1NF and:
A. It has no foreign keys
 B. It has no partial dependency on a candidate key
 C. It has no transitive dependencies
 D. Every attribute is a primary key
Correct Answer: B
Explanation: 2NF eliminates partial dependencies, meaning every non-key attribute must depend on the entire candidate key, not just part of a composite key.
3. Third Normal Form (3NF)
Which type of dependency does 3NF primarily eliminate?
A. Functional dependency
 B. Partial dependency
 C. Transitive dependency
 D. Multivalued dependency
Correct Answer: C
Explanation: 3NF eliminates transitive dependencies, where a non-key attribute depends on another non-key attribute rather than directly on the key.
4. Identifying 2NF
Consider the relation:
ENROLLMENT(Student_ID, Course_ID, Student_Name, Course_Name, Grade)
The primary key is (Student_ID, Course_ID). Which attribute creates a partial dependency?
A. Grade
 B. Course_ID
 C. Student_Name
 D. Student_ID
Correct Answer: C
Explanation: Student_Name depends only on Student_ID, which is part of the composite key, so it creates a partial dependency and violates 2NF.
5. Identifying 3NF
Consider the relation:
STUDENT(Student_ID, Student_Name, Department_ID, Department_Name)
Given that Student_ID → Department_ID and Department_ID → Department_Name, what normalization problem exists?
A. Violation of 1NF
 B. Partial dependency
 C. Transitive dependency
 D. Multivalued dependency
Correct Answer: C
Explanation: Department_Name depends on Department_ID, which depends on Student_ID, creating a transitive dependency that violates 3NF.""",
            "optimized_prompt": """For university DBMS exam prep, generate 5 practice MCQs on database normalization (1NF, 2NF, 3NF). Ensure the output includes:
4 distinct options per question.
The clearly indicated correct answer.
A brief explanation for each answer.""",
            "optimized_output": """DBMS Normalization — Practice MCQs
1. What is the main requirement of First Normal Form (1NF)?
A. Eliminate transitive dependencies
 B. Eliminate partial dependencies
 C. Ensure all attributes contain atomic values
 D. Remove all foreign keys
Correct Answer: C
Explanation: A relation is in 1NF when each attribute contains a single, indivisible value and there are no repeating groups.
2. A relation is in Second Normal Form (2NF) when it is in 1NF and:
A. It has no transitive dependencies
 B. It has no partial dependencies
 C. All attributes are multivalued
 D. It has no candidate keys
Correct Answer: B
Explanation: 2NF eliminates partial dependencies, where a non-key attribute depends on only part of a composite primary key.
3. Which dependency must be removed to achieve Third Normal Form (3NF)?
A. Functional dependency
 B. Partial dependency
 C. Transitive dependency
 D. Candidate-key dependency
Correct Answer: C
Explanation: 3NF requires that non-key attributes do not depend on other non-key attributes through a transitive dependency.
4. Consider the relation ENROLLMENT(Student_ID, Course_ID, Student_Name, Grade) with primary key (Student_ID, Course_ID). If Student_ID → Student_Name, which normal form is violated?
A. 1NF
 B. 2NF
 C. 3NF
 D. None
Correct Answer: B
Explanation: Student_Name depends only on part of the composite key (Student_ID), creating a partial dependency and violating 2NF.
5. Consider STUDENT(Student_ID, Student_Name, Department_ID, Department_Name). If Student_ID → Department_ID and Department_ID → Department_Name,what problem exists?
A. Repeating group
 B. Partial dependency
 C. Transitive dependency
 D. Atomicity violation
Correct Answer: C
Explanation: Department_Name indirectly depends on Student_ID through Department_ID, creating a transitive dependency and violating 3NF.
Pair 2.2"""
        },
        {
            "baseline_prompt": """I am studying for my university Operating Systems mid-term exam and I want to practice answering conceptual short questions. Could you please generate 3 short-answer exam questions about CPU scheduling algorithms like Round Robin and SJF? Please provide a concise standard answer for each question so I can grade myself after attempting them.""",
            "baseline_output": """Question 1 — Round Robin
What is the Round Robin (RR) CPU scheduling algorithm, and what is the role of the time quantum?
Standard Answer:
 Round Robin is a preemptive CPU scheduling algorithm in which each process is given a fixed time interval called a time quantum. When the quantum expires, the running process is preempted and moved to the end of the ready queue, allowing the next process to execute. A smaller quantum generally improves responsiveness but increases context-switching overhead.
Question 2 — Shortest Job First (SJF)
What is Shortest Job First (SJF) scheduling, and what is its main advantage?
Standard Answer:
 SJF selects the process with the shortest expected CPU burst time for execution. It can be either non-preemptive or related to the preemptive Shortest Remaining Time First (SRTF) approach. Its main advantage is that, when burst times are known accurately, SJF generally provides the minimum average waiting time among scheduling algorithms.
Question 3 — Comparing RR and SJF
State one major difference between Round Robin and SJF scheduling.
Standard Answer:
 Round Robin is preemptive and designed to provide fair CPU access and good responsiveness, giving each process a fixed time quantum. SJF selects the process with the shortest CPU burst and focuses primarily on minimizing average waiting time. Thus, RR is commonly suitable for time-sharing systems, while SJF is useful when CPU burst times can be estimated accurately.""",
            "optimized_prompt": """For an Operating Systems exam review, generate 3 short-answer theoretical questions on CPU scheduling (SJF, Round Robin, FCFS). Ensure the output includes:
Clear conceptual questions.
Concise model answers (max 3 sentences each).""",
            "optimized_output": """Operating Systems — CPU Scheduling Review
1. Shortest Job First (SJF)
Question: What is the Shortest Job First (SJF) scheduling algorithm, and what is its main advantage?
Model Answer: SJF selects the process with the shortest expected CPU burst for execution. Its main advantage is that it generally minimizes the average waiting time when CPU burst lengths can be estimated accurately.
2. Round Robin (RR)
Question: How does Round Robin scheduling work, and why is the time quantum important?
Model Answer: Round Robin assigns each ready process a fixed time quantum and cycles through them in a circular queue. When the quantum expires, the running process is preempted and placed at the end of the queue, providing fair CPU access and good responsiveness.
3. First-Come, First-Served (FCFS)
Question: What is FCFS scheduling, and what is one major disadvantage of this algorithm?
Model Answer: FCFS executes processes in the order they arrive in the ready queue and is generally non-preemptive. Its major disadvantage is the convoy effect, where short processes may have to wait a long time behind a long-running process.
Pair 2.3"""
        },
        {
            "baseline_prompt": """I need to practice mathematical proofs and time complexity derivations for my university Data Structures and Algorithms final exam. Can you give me 1 practice problem where I have to solve recurrences using the Master Theorem? Please state the problem clearly and then provide a step-by-step mathematical solution for each so I can double-check my steps.""",
            "baseline_output": """Practice Problem — Master Theorem
Problem
Give one recurrence similar to:
T(n) = 2T(n/2) + n
Ask me to determine its asymptotic time complexity using the Master Theorem.
Step-by-Step Solution
Solve the recurrence completely and clearly.
Step 1: Identify a, b, and f(n)
First write the standard Master Theorem form:
T(n) = aT(n/b) + f(n)
Then clearly identify:
a = ...
b = ...
f(n) = ...
Step 2: Calculate n^(log_b a)
Show the calculation step by step.
For example:
n^(log_2 2)
Since:
log_2 2 = 1
Therefore:
n^(log_2 2) = n
Step 3: Compare f(n) with n^(log_b a)
Clearly compare the two expressions and explain whether they are smaller, equal, or larger.
Then explicitly state which Master Theorem case applies:
Case 1
Case 2
or Case 3
Step 4: Apply the appropriate Master Theorem case
Show the formula for the selected case and substitute the values step by step.
Final Answer
Clearly state the final asymptotic complexity in a boxed format, for example:
T(n) = Θ(n log n)""",
            "optimized_prompt": """For an Algorithms exam, create 1 recurrence relation practice problem solved via the Master Theorem. Provide:
Explicit recurrence equations $T(n)$.
Step-by-step mathematical solution derivations.
Final Big-O time complexity bounds.""",
            "optimized_output": """# Algorithms Exam Practice Problem: Master Theorem
## Practice Problem
Solve the following recurrence relation using the Master Theorem:
T(n) = 4 T(n/2) + n
Assume base case T(1) = \\Theta(1) and n is a power of 2.
## Step-by-Step Solution Derivation
### Step 1: Identify the Master Theorem Parameters
The general form for the Master Theorem recurrence is:
T(n) = a T(n/b) + f(n)
Matching T(n) = 4 T(n/2) + n against the general form yields:
a = 4: The number of subproblems generated at each recursive step (a >= 1).
b = 2: The factor by which the input size is reduced (b > 1).
f(n) = n: The work done outside the recursive calls (combining and dividing step).
### Step 2: Compute the Critical Exponent n^(log_b a)
Calculate the watershed/critical function n^(log_b a):
log_b a = log_2 4 = 2
So, the critical boundary function is:
n^(log_b a) = n^2
### Step 3: Compare f(n) with n^(log_b a)
We now compare f(n) = n against n^(log_b a) = n^2:
f(n) = n grows strictly slower than n^(log_b a) = n^2.
Specifically, f(n) = O(n^(2 - \\epsilon)) for any \\epsilon where 0 < \\epsilon <= 1. (Choosing \\epsilon = 1 gives f(n) = O(n^(2-1)) = O(n)).
Because f(n) is polynomially smaller than n^(log_b a), the work done at the leaves dominates the total execution time.
### Step 4: Apply the Master Theorem (Case 1)
According to Case 1 of the Master Theorem:
If f(n) = O(n^(log_b a - \\epsilon)) for some constant \\epsilon > 0, then:
T(n) = \\Theta(n^(log_b a))
Substituting our values:
T(n) = \\Theta(n^2)
## Final Time Complexity Bound
The exact tight bound for the recurrence is:
T(n) = \\Theta(n^2)
In terms of upper bound:
T(n) = O(n^2)
Pair 2.4"""
        },
        {
            "baseline_prompt": """I have a Computer Networks exam coming up that includes practical scenario questions. Can you generate 2 realistic network troubleshooting scenarios involving IP routing and subnetting issues? Please describe the scenario problem and then give a structured bulleted solution explaining how to diagnose and resolve the network issue.""",
            "baseline_output": """# Network Troubleshooting Scenario: VLSM Subnet Mask Mismatch & Incomplete Route Summarization
## Scenario Description
An enterprise network connects Headquarters (**Router-HQ**) to a Remote Branch (**Router-BR**) via a point-to-point serial link (`10.0.0.0/30`).
Router-HQ LAN:** `192.168.1.0/24` (Gateway: `192.168.1.1`)
Router-BR WAN Interface:** `10.0.0.2/30`
Router-HQ WAN Interface:** `10.0.0.1/30`
To accommodate growth, the Branch network was divided into two subnets using Variable Length Subnet Masking (VLSM):
Engineering Dept (VLAN 10):** `192.168.2.0/25` (Valid hosts: `192.168.2.1` – `192.168.2.126`; Gateway: `192.168.2.1`)
Operations Dept (VLAN 20):** `192.168.2.128/25` (Valid hosts: `192.168.2.129` – `192.168.2.254`; Gateway: `192.168.2.129`)
Configuration Errors:
1. On **Router-HQ**, the administrator added a static route for the Branch using a `/25` mask instead of summarizing the entire `/24` block:
`ip route 192.168.2.0 255.255.255.128 10.0.0.2`
2. On **Router-BR**, a junior technician configured the Operations interface (`192.168.2.129`) with a `/24` subnet mask (`255.255.255.0`) instead of `/25` (`255.255.255.128`).
Symptoms:
Engineering hosts** (`192.168.2.50`) have full bi-directional connectivity with HQ hosts (`192.168.1.100`).
Operations hosts** (`192.168.2.150`) can ping their local gateway (`192.168.2.129`), but **cannot** ping HQ hosts (`192.168.1.100`).
HQ hosts** (`192.168.1.100`) receive "Destination Host Unreachable" when attempting to ping Operations hosts (`192.168.2.150`).
## Diagnostic & Resolution Steps
Step 1: Analyze Inbound Routing Table at Router-HQ
Check the routing table on **Router-HQ**:
```text
show ip route
```
Observe the entry: `S 192.168.2.0/25 [1/0] via 10.0.0.2`.
Diagnosis:** **Router-HQ** only knows how to reach `192.168.2.0` through `192.168.2.127`. When HQ host `192.168.1.100` sends a packet to Operations host `192.168.2.150`, **Router-HQ** drops the traffic because it lacks a matching route for the `192.168.2.128/25` block.
Step 2: Inspect Interface Configuration on Router-BR
Check the interface settings on **Router-BR**:
```text
show ip interface brief
show running-config interface GigabitEthernet0/0/2
```
Observe that interface `Gi0/0/2` (Operations) is configured as:
`ip address 192.168.2.129 255.255.255.0`
Diagnosis:** Because the mask is set to `/24`, **Router-BR** treats the range `192.168.2.0` – `192.168.2.255` as a single directly connected broadcast domain. This creates an overlapping route conflict with interface `Gi0/0/1` (Engineering, `192.168.2.1/25`), causing ARP and packet forwarding errors between internal VLANs on **Router-BR**.
Step 3: Execute Path and ARP Troubleshooting
From HQ Host (`192.168.1.100`), run a traceroute:
```bash
tracert 192.168.2.150
```
Result:* The trace fails at the first hop (**Router-HQ**, `192.168.1.1`) because **Router-HQ** has no route to `192.168.2.150`.
From Operations Host (`192.168.2.150`), run a traceroute:
```bash
tracert 192.168.1.100
```
Result:* Packets reach **Router-BR** (`192.168.2.129`) but fail to return due to local interface subnet overlaps.
Step 4: Resolve Configuration Issues
Fix 1 (Router-HQ):** Update the static route on **Router-HQ** to summarize both `/25` subnets into a single `/24` route:
```text
Router-HQ(config)# no ip route 192.168.2.0 255.255.255.128 10.0.0.2
Router-HQ(config)# ip route 192.168.2.0 255.255.255.0 10.0.0.2
```
Fix 2 (Router-BR):** Correct the subnet mask on the Operations interface to `/25`:
```text
Router-BR(config)# interface GigabitEthernet0/0/2
Router-BR(config-if)# ip address 192.168.2.129 255.255.255.128
```
Step 5: Verify End-to-End Resolution
Verify the routing table on **Router-HQ** contains `192.168.2.0/24 via 10.0.0.2`.
From Operations host (`192.168.2.150`), execute `ping 192.168.1.100`.
From HQ host (`192.168.1.100`), execute `ping 192.168.2.150` to confirm full bi-directional communication across all subnets.""",
            "optimized_prompt": """For a university Computer Networks exam, generate 1 scenario-based troubleshooting problems regarding IP subnetting. Ensure the output provides:
Problem scenario description.
Step-by-step diagnosis procedure.
Correct solution and network configuration fix.""",
            "optimized_output": """# Scenario-Based Troubleshooting: IP Subnetting Mask Mismatch
## Problem Scenario Description
An enterprise organization allocates the IP block **`10.10.0.0/22`** for its corporate campus. To support a growing Engineering department, the network architect assigned a `/23` block (`10.10.0.0/23`) to the Engineering VLAN (VLAN 10).
### Network Settings:
Subnet Assigned:** `10.10.0.0/23`
Subnet Mask:** `255.255.254.0`
Default Gateway (Router Gi0/0.10):** `10.10.0.1`
Valid Host Range:** `10.10.0.1` – `10.10.1.254`
A new workstation, **ENG-PC2**, is assigned IP address `10.10.1.100`. During manual setup, a network intern configured the host with the following parameters:
IP Address:** `10.10.1.100`
Subnet Mask:** `255.255.255.0` (`/24`)
Default Gateway:** `10.10.0.1`
### Reported Symptoms:
1. **ENG-PC2** can successfully ping older Engineering workstations located in the `10.10.1.1` – `10.10.1.254` range (e.g., `10.10.1.50`).
2. **ENG-PC2** **cannot** ping workstations located in the `10.10.0.2` – `10.10.0.255` range (e.g., `10.10.0.45`), despite them being in the same physical VLAN and switch.
3. **ENG-PC2** cannot ping its Default Gateway (`10.10.0.1`) and has no connectivity to other VLANs or the internet.
## Step-by-Step Diagnosis Procedure
### Step 1: Analyze the Subnet Math & Local Range
Intended `/23` Subnet:
Network ID: `10.10.0.0`
Subnet Mask: `255.255.254.0`
Usable IPs: `10.10.0.1` through `10.10.1.254`
Gateway (`10.10.0.1`) and Host (`10.10.1.100`) are in the **same** logical `/23` subnet.
Misconfigured `/24` Subnet on Host:
Network ID: `10.10.1.0`
Subnet Mask: `255.255.255.0`
Usable Local IPs: `10.10.1.1` through `10.10.1.254`
### Step 2: Trace Host Routing Logic (Why Intra-VLAN Communication Fails)
When **ENG-PC2** (`10.10.1.100`) attempts to send a packet to `10.10.0.45`:
1. **ENG-PC2** performs a bitwise AND operation using its configured mask (`255.255.255.0`) on the target IP (`10.10.0.45`).
2. It determines that `10.10.0.45` belongs to network `10.10.0.0/24`, which is **different** from its own local network (`10.10.1.0/24`).
3. Because the destination is deemed "remote," **ENG-PC2** decides it must forward the packet to its Default Gateway (`10.10.0.1`).
### Step 3: Identify Default Gateway Unreachability
1. **ENG-PC2** checks the Default Gateway IP (`10.10.0.1`) against its own network address (`10.10.1.0/24`).
2. It discovers that `10.10.0.1` is **also outside** its local `/24` subnet boundaries.
3. Operating system TCP/IP stacks treat a default gateway outside the local subnet as an invalid off-link address. **ENG-PC2** cannot resolve the Gateway's MAC address via local ARP, causing all off-network traffic to immediately fail.
## Correct Solution & Network Configuration Fix
### Solution 1: Host Operating System Fix (Static Assignment)
Correct the Subnet Mask on **ENG-PC2** to match the `/23` prefix length.
Windows Network Interface Settings:
```text
IP Address:      10.10.1.100
Subnet Mask:     255.255.254.0   <-- (Changed from 255.255.255.0)
Default Gateway: 10.10.0.1"""
        },
        {
            "baseline_prompt": """I am revising key definitions and concepts for my university Object-Oriented Programming exam tomorrow. Can you create 3 flashcard style revision prompts covering OOP core concepts like Encapsulation, Polymorphism, and Abstraction? Please present them with a front question and a clear back answer so I can quickly test my memory.""",
            "baseline_output": """""",
            "optimized_prompt": """For an Object-Oriented Programming exam revision, create 3 study flashcard pairs (Question and Answer) covering core principles. Provide:
Clear front-side conceptual questions.
Concise back-side answer definitions (max 2 sentences each).""",
            "optimized_output": """"""
        },
    ],
    "Programming Help": [
        {
            "baseline_prompt": """I am working on a lab assignment for my university Computer Science course and I am trying to write a Python code to calculate the factorial of a number using recursion. However, my program is throwing a maximum recursion depth exceeded error when I run it. Can you please look at my code, explain what is wrong with the logic, provide the corrected code, and show how the function calls resolve for factorial(4) so I can complete my lab report?
Code:
def factorial(n):
return n * factorial(n - 1)
print(factorial(5))""",
            "baseline_output": """The problem is that your recursive function has no base case. It keeps calling factorial(n - 1) indefinitely, eventually reaching Python's recursion limit.
Corrected Python Code
def factorial(n):
# Base case
if n == 0 or n == 1:
return 1
# Recursive case
return n * factorial(n - 1)
print(factorial(5))""",
            "optimized_prompt": """Debug this Python recursive factorial function for a CS lab assignment:
def factorial(n):
return n * factorial(n - 1)
Provide the following:
1. Explanation of the logical bug causing the error.
2. Corrected code including base cases (n <= 1).
3. Brief call stack trace for factorial(4).""",
            "optimized_output": """120
3. Call Stack Trace for factorial(4)
The calls proceed downward:
factorial(4)
↓
4 * factorial(3)
↓
4 * (3 * factorial(2))
↓
4 * (3 * (2 * factorial(1)))
At factorial(1), the base case returns 1. The results then resolve backward:
factorial(1) = 1
factorial(2) = 2 * 1 = 2
factorial(3) = 3 * 2 = 6
factorial(4) = 4 * 6 = 24
Final result:
factorial(4) = 24
Pair 3.2"""
        },
        {
            "baseline_prompt": """While solving  a programming problem where I need to find duplicate elements in an integer array. My current Python implementation uses nested loops and runs very slowly O(n^2) on large inputs. Can you help me refactor this code to make it run faster in O(n) time using a Hash Set? Please provide the refactored code and explain how the time complexity improves.
Code:
def find_duplicates(arr):
dups = []
for i in range(len(arr)):
for j in range(i + 1, len(arr)):
if arr[i] == arr[j] and arr[i] not in dups:
dups.append(arr[i])
return dups""",
            "baseline_output": """Your current solution compares many pairs of elements, which makes it O(n²). A hash set lets us check whether an element has already appeared in average O(1) time.
Refactored Code
def find_duplicates(arr):
seen = set()
duplicates = set()
for num in arr:
if num in seen:
duplicates.add(num)
else:
seen.add(num)
return list(duplicates)
How it works
For each element:
Check whether num is already in seen.
If it is, the element is a duplicate, so add it to duplicates.
Otherwise, add it to seen.
For example:
arr = [1, 2, 3, 2, 4, 1, 5]
print(find_duplicates(arr))
Possible output:
[1, 2]
Time Complexity
Original approach:
The nested loops compare pairs of elements:
[
O(n^2)
]
For large arrays, this becomes slow because the number of comparisons grows quadratically.
Hash-set approach:
The loop processes each element once, while set lookup and insertion take average O(1):
[
n \\times O(1) = O(n)
]
Therefore:
[
\\boxed{O(n)}
]
The additional space complexity is O(n) because the seen and duplicates sets can store up to (n) elements.""",
            "optimized_prompt": """Refactor this O(n^2) Python duplicate detection function for a CS lab to achieve O(n) time complexity using a Hash Set:
def find_duplicates(arr):
dups = []
for i in range(len(arr)):
for j in range(i + 1, len(arr)):
if arr[i] == arr[j] and arr[i] not in dups:
dups.append(arr[i])
return dups
Address the following:
1. Optimized Python code using set operations.
2. Brief explanation of how time complexity improves from O(n^2) to O(n).""",
            "optimized_output": """Here is the optimized version, suitable for your CS lab report.
1. Optimized Python Code
def find_duplicates(arr):
seen = set()
duplicates = set()
for num in arr:
if num in seen:
duplicates.add(num)
else:
seen.add(num)
return list(duplicates)
2. Complexity Improvement
The original implementation uses nested loops, comparing elements in pairs. Therefore, it may perform approximately (n^2) comparisons, giving a time complexity of O(n²).
The optimized version scans the array only once. Hash-set operations such as in and add have an average time complexity of O(1).
Thus, for (n) elements:
[
n \\times O(1) = O(n)
]
Therefore, the optimized algorithm has an average time complexity of O(n), although it uses O(n) additional space for the sets.
Summary:
Original: O(n²) time
Optimized: O(n) average time
Extra space: O(n)
Pair 3.3"""
        },
        {
            "baseline_prompt": """For my university Algorithms assignment, I need to convert an iterative Fibonacci sequence function in C++ into a recursive function. Could you please rewrite the code using recursion instead of a for loop? Make sure to include the corrected code, explain how base cases are handled, and state any performance considerations like stack overhead.
Code:
int fibonacci(int n) {
int a = 0, b = 1, c;
if (n == 0) return a;
for (int i = 2; i <= n; i++) {
c = a + b;
a = b;
b = c;
}
return b;
}""",
            "baseline_output": """Recursive Fibonacci in C++
The iterative version can be converted by defining the Fibonacci sequence recursively:
[
F(n)=F(n-1)+F(n-2)
]
with the base cases (F(0)=0) and (F(1)=1).
int fibonacci(int n) {
// Base cases
if (n == 0)
return 0;
if (n == 1)
return 1;
// Recursive case
return fibonacci(n - 1) + fibonacci(n - 2);
}
For example:
#include <iostream
using namespace std;
int fibonacci(int n) {
if (n == 0)
return 0;
if (n == 1)
return 1;
return fibonacci(n - 1) + fibonacci(n - 2);
}
int main() {
cout << fibonacci(6);
return 0;
}""",
            "optimized_prompt": """Convert this iterative C++ Fibonacci function into a recursive implementation for an Algorithms assignment:
int fibonacci(int n) {
int a = 0, b = 1, c;
if (n == 0) return a;
for (int i = 2; i <= n; i++) {
c = a + b;
a = b;
b = c;
}
return b;
}
Provide:
1. Equivalent recursive C++ code handling base cases (n = 0, n = 1).
2. Brief note on call stack overhead during execution.""",
            "optimized_output": """1. Recursive C++ Implementation
int fibonacci(int n) {
// Base cases
if (n == 0)
return 0;
if (n == 1)
return 1;
// Recursive case
return fibonacci(n - 1) + fibonacci(n - 2);
}
The base cases handle n = 0 and n = 1, preventing infinite recursion. For larger values, the function recursively calculates the two preceding Fibonacci numbers and adds them.
2. Call Stack Overhead
Each recursive call creates a new stack frame containing information such as parameters and the return address. The maximum recursion depth is O(n), so the recursive implementation requires O(n) stack space and can cause significant stack overhead for large n.
Additionally, this straightforward recursive version has O(2ⁿ) time complexity because it repeatedly recalculates the same Fibonacci values.
Pair 3.4"""
        },
        {
            "baseline_prompt": """I am writing Java code for a university Software Testing assignment where I need to make a array average calculation function robust. Right now, passing an empty array or null input crashes the program with ArithmeticException or NullPointerException. Can you help me fix this function so it safely handles empty arrays and null pointers without crashing?
Code:
public double calculateAverage(int[] numbers) {
int sum = 0;
for (int num : numbers) {
sum += num;
}
return (double) sum / numbers.length;
}""",
            "baseline_output": """The two problems are:
numbers == null → the enhanced for loop causes a NullPointerException.
Empty array → numbers.length is 0, so the division is invalid. In Java, because the numerator is converted to double, this produces NaN rather than an ArithmeticException; however, it is still usually undesirable for an average function.
A robust approach is to explicitly validate the input and return a defined value or throw an appropriate exception.
Corrected Java Code
public double calculateAverage(int[] numbers) {
if (numbers == null || numbers.length == 0) {
return 0.0;
}
int sum = 0;
for (int num : numbers) {
sum += num;
}
return (double) sum / numbers.length;
}
How it works
numbers == null checks for a null reference before accessing the array.
numbers.length == 0 prevents calculation on an empty array.
For either invalid case, the method returns 0.0.
Otherwise, it calculates the average normally.
For example:
calculateAverage(new int[]{10, 20, 30}); // 20.0
calculateAverage(new int[]{});           // 0.0
calculateAverage(null);                  // 0.0
Testing note: In a production application, you might instead throw IllegalArgumentException for null/empty input if 0.0 could be confused with a legitimate average.""",
            "optimized_prompt": """Add robust edge-case handling to this Java array average function for a Software Testing lab:
public double calculateAverage(int[] numbers) {
int sum = 0;
for (int num : numbers) {
sum += num;
}
return (double) sum / numbers.length;
}
Provide:
1. Corrected Java code handling null array reference and empty array (length == 0).
2. Brief explanation of defensive programming checks added.""",
            "optimized_output": """1. Corrected Java Code
public double calculateAverage(int[] numbers) {
// Defensive checks for invalid input
if (numbers == null || numbers.length == 0) {
return 0.0;
}
int sum = 0;
for (int num : numbers) {
sum += num;
}
return (double) sum / numbers.length;
}
2. Defensive Programming Checks
numbers == null prevents a NullPointerException when no array reference is provided.
numbers.length == 0 prevents an average calculation on an empty array.
Returning 0.0 provides a defined result for these edge cases instead of allowing invalid input to cause unexpected behavior.
The checks occur before accessing or iterating over the array, ensuring the method safely handles both cases.
Pair 3.5"""
        },
        {
            "baseline_prompt": """I am building a project for my university Web Engineering lab and I am having trouble fetching JSON data from an API. My function prints Promise { <pending> } instead of the actual data because I am not handling the async response properly. Can you please look at my JavaScript code, fix the asynchronous issue using async/await, and explain why it wasn't working initially?
Code:
function fetchUserData() {
let response = fetch("https://api.example.com/users");
console.log(response);
}""",
            "baseline_output": """The issue is that fetch() is asynchronous and immediately returns a Promise. Your original code logs that Promise before the HTTP request has finished.
Corrected JavaScript Using async/await
async function fetchUserData() {
try {
const response = await fetch("https://api.example.com/users");
if (!response.ok) {
throw new Error(`HTTP error: ${response.status}`);
}
const data = await response.json();
console.log(data);
return data;
} catch (error) {
console.error("Failed to fetch user data:", error);
}
}
fetchUserData();
Why the Original Code Failed
Your original code does this:
let response = fetch("https://api.example.com/users");
console.log(response);
fetch() returns a Promise, representing a future result. Therefore, console.log() displays something like:
Promise { <pending> }
Using await pauses the async function until the Promise resolves:
const response = await fetch(...);
Then response.json() is also asynchronous, so it must be awaited:
const data = await response.json();
The try...catch additionally handles network or HTTP-related errors, making the function more robust.""",
            "optimized_prompt": """Debug this JavaScript API fetch function for a Web Engineering lab task:
function fetchUserData() {
let response = fetch("https://api.example.com/users");
console.log(response);
}
Provide:
1. Explanation of why logging unhandled Promise returns pending.
2. Corrected implementation utilizing async/await and .json().
3. Brief explanation of asynchronous execution flow.""",
            "optimized_output": """1. Why does it log Promise { <pending> }?
fetch() is asynchronous and immediately returns a Promise representing the future HTTP response. The original code logs that Promise before the network request has completed, so the result appears as Promise { <pending> }.
2. Corrected Implementation
async function fetchUserData() {
try {
const response = await fetch("https://api.example.com/users");
const data = await response.json();
console.log(data);
return data;
} catch (error) {
console.error("Error fetching user data:", error);
}
}
fetchUserData();
3. Asynchronous Execution Flow
fetchUserData() starts executing and calls fetch().
await fetch() waits for the Promise to resolve without blocking the browser's main thread.
Once the HTTP response arrives, execution continues and response.json() asynchronously parses the response body.
await response.json() provides the parsed JavaScript object.
console.log(data) then displays the actual API data instead of the pending Promise.
Thus, async/await makes the asynchronous code easier to read while still preserving JavaScript's non-blocking execution model."""
        },
    ],
    "Concept Learning": [
        {
            "baseline_prompt": """I am taking a university Machine Learning course and I need help understanding a core concept for my studies. Can you please explain what overfitting means in machine learning? Please define what it is, explain the main causes behind why it happens in models, give one real-world example to illustrate the concept clearly, and describe three standard techniques used to prevent it so that I can understand it thoroughly for my course.""",
            "baseline_output": """Overfitting in Machine Learning
Overfitting occurs when a machine learning model learns the training data too closely, including its noise and random patterns, instead of learning general patterns that apply to new data. As a result, the model performs very well on training data but poorly on unseen or test data.
Main Causes
Excessive model complexity: A model with too many parameters or layers can memorize training examples rather than learn general relationships.
Insufficient training data: A small dataset may not represent the wider population, making it easier for the model to memorize individual examples.
Noisy or irrelevant features: The model may learn random variations or irrelevant characteristics that do not generalize to new observations.
Real-World Example
Suppose a model is trained to identify cats from photographs. If the training images mostly show cats indoors, the model might incorrectly learn that indoor backgrounds indicate a cat rather than recognizing characteristics of cats themselves. It may perform extremely well on training images but fail when shown a cat outdoors.
Three Ways to Prevent Overfitting
Cross-validation: Evaluate the model across multiple training and validation splits to assess how well it generalizes.
Regularization: Add a penalty for overly complex models, encouraging simpler parameter values. Common methods include L1 and L2 regularization.
Early stopping: Stop training when validation performance stops improving, preventing the model from continuing to memorize training data.
In short: Overfitting means excellent performance on training data but poor generalization to unseen data.""",
            "optimized_prompt": """For a university Machine Learning course, explain the concept of overfitting by covering:
1. Definition of the concept.
2. Primary causes of overfitting.
3. One real-world example.
4. Three standard prevention techniques.""",
            "optimized_output": """Overfitting in Machine Learning
1. Definition
Overfitting occurs when a machine learning model learns the training data too closely, including noise and insignificant patterns. Consequently, it performs very well on training data but performs poorly on unseen or test data.
2. Primary Causes
Excessive model complexity: Models with too many parameters can memorize training examples instead of learning general patterns.
Insufficient training data: Small or unrepresentative datasets make memorization easier.
Noisy or irrelevant data: The model may learn random variations that do not represent meaningful relationships.
Excessive training: Training a model for too many iterations can cause it to increasingly fit the training data rather than generalize.
3. Real-World Example
Consider a model designed to detect spam emails. If it memorizes specific words or phrases appearing in the training emails, it may correctly classify those examples but incorrectly classify new spam messages using different wording. This indicates that the model has learned the training examples rather than the general characteristics of spam.
4. Three Prevention Techniques
Cross-validation: Evaluate the model on different subsets of data to measure its ability to generalize.
Regularization: Penalize model complexity using techniques such as L1 or L2 regularization.
Early stopping: Stop training when performance on validation data stops improving, preventing excessive fitting to training data.
Key idea: A well-generalized model should perform consistently well on both training and previously unseen data.
Pair 4.2"""
        },
        {
            "baseline_prompt": """I want to know about a university Web Engineering course and I need help understanding a core concept for my studies. Can you please explain what a RESTful API means in web development? Please define what it is, explain the main architectural principles behind how it works, give one real-world example to illustrate the concept clearly, and describe three common HTTP methods used in REST APIs so that I can understand it thoroughly for my course.""",
            "baseline_output": """RESTful API in Web Development
1. Definition
A RESTful API (Representational State Transfer API) is a web API that allows different software systems to communicate over HTTP using a set of architectural principles. It typically exposes resources, such as users, products, or orders, through URLs and allows clients to perform operations on those resources using standard HTTP methods.
2. Main Architectural Principles
REST commonly emphasizes:
Client-server architecture: The client (such as a web or mobile application) and server are separated, allowing them to evolve independently.
Statelessness: Each request contains the information necessary to process it; the server does not rely on previous requests to understand the current request.
Resource-based design: Data and functionality are represented as resources identified by URLs, such as /users/25.
Uniform interface: Standard HTTP methods and consistent resource representations make APIs predictable.
Cacheability: Responses can indicate whether they may be cached to improve performance.
3. Real-World Example
Consider an online shopping application. A REST API might provide /products/101 to represent a particular product. A frontend application can request that resource to display its name, price, and availability.
4. Three Common HTTP Methods
In summary: RESTful APIs provide a standardized, scalable way for clients and servers to exchange information using HTTP and resource-oriented operations.""",
            "optimized_prompt": """For a university Web Engineering course, explain the concept of RESTful APIs by covering:
1. Definition of RESTful APIs.
2. Core architectural principles.
3. One real-world example.
4. Three standard HTTP methods (GET, POST, PUT/DELETE) and their functions.""",
            "optimized_output": """RESTful APIs
1. Definition
A RESTful API is an application programming interface that follows the principles of REST (Representational State Transfer) to enable communication between clients and servers over HTTP. It represents data as resources, usually identified by URLs, and uses standard HTTP methods to perform operations on those resources.
2. Core Architectural Principles
The main REST principles include:
Client-server architecture: The client and server have separate responsibilities, allowing them to develop independently.
Statelessness: Each request contains all information needed by the server; the server does not depend on previous requests.
Resource-based design: Resources such as users, products, or orders are identified through URLs.
Uniform interface: Standard HTTP methods provide consistent ways to interact with resources.
Cacheability: Responses can be cached when appropriate to improve performance.
3. Real-World Example
An online shopping system could provide:
/api/products/101
This endpoint represents product 101. A web application can use the API to retrieve product information, create products, update product details, or remove products.
4. Standard HTTP Methods
In summary, RESTful APIs provide a standardized and scalable approach for communication between web clients and servers through resources, URLs, and HTTP methods.
Pair 4.3"""
        },
        {
            "baseline_prompt": """I am studying for my university Operating Systems module and I'm having trouble grasping Virtual Memory. Can you explain the concept of Virtual Memory and how paging works? Please define virtual memory, list two major benefits it offers to modern OSs, explain page tables briefly with a simple example, and define what a page fault is so I can grasp the concept properly.""",
            "baseline_output": """Virtual Memory and Paging
1. What is Virtual Memory?
Virtual memory is a memory-management technique that allows an operating system to give each process the illusion of having a large, continuous memory space, even when physical RAM is limited. The OS uses RAM and secondary storage (such as an SSD) to provide this abstraction.
2. Two Major Benefits
Larger address space: Programs can use more memory than the amount of available physical RAM, because inactive pages can be stored on disk.
Process isolation and protection: Each process has its own virtual address space, helping prevent one process from directly accessing another process's memory.
3. How Paging and Page Tables Work
Paging divides virtual memory into fixed-size pages and physical memory into equally sized frames. A page table maintained by the OS maps virtual pages to physical frames.
For example, suppose:
Virtual Page 0 → Physical Frame 5
Virtual Page 1 → Physical Frame 2
Virtual Page 2 → Physical Frame 8
If a program accesses virtual page 1, the page table tells the CPU that it is stored in physical frame 2. The virtual address is divided into a page number and an offset; the page number is used to locate the corresponding frame while the offset identifies the exact location within that frame.
4. What is a Page Fault?
A page fault occurs when a process tries to access a virtual page that is not currently loaded in physical RAM. The OS temporarily pauses the process, retrieves the required page from secondary storage into a free frame (or replaces another page), updates the page table, and then resumes the process.
Key idea:
Virtual page → Page table → Physical frame → Actual data in RAM.""",
            "optimized_prompt": """For a university Operating Systems course, explain Virtual Memory and Paging covering:
1. Definition of Virtual Memory.
2. Two core benefits to modern operating systems.
3. How Page Tables map virtual addresses to physical memory.
4. Definition of a Page Fault.""",
            "optimized_output": """Virtual Memory and Paging
1. Definition of Virtual Memory
Virtual memory is a memory-management technique that gives each process the appearance of having a large, continuous memory space, even when physical RAM is limited. The operating system uses address translation and secondary storage to manage this abstraction.
2. Two Core Benefits
Efficient memory utilization: Programs can use a virtual address space larger than available physical RAM because inactive pages can be stored on secondary storage.
Memory protection and isolation: Each process has its own virtual address space, helping prevent processes from accessing each other's memory without permission.
3. How Page Tables Work
Paging divides virtual memory into fixed-size pages and physical memory into equally sized frames. A page table maps each virtual page to its corresponding physical frame.
For example:
Virtual Page 0 → Physical Frame 4
Virtual Page 1 → Physical Frame 7
Virtual Page 2 → Physical Frame 1
If a virtual address belongs to page 1, the page table identifies frame 7 as its physical location. The address also contains an offset, which specifies the exact position within that page/frame.
Thus:
Virtual Address → Page Number + Offset → Page Table → Physical Frame + Offset
4. Definition of a Page Fault
A page fault occurs when a process attempts to access a virtual page that is not currently present in physical RAM. The operating system loads the required page from secondary storage into RAM, updates the page table, and then allows the process to continue.
Pair 4.4"""
        },
        {
            "baseline_prompt": """I need to learn about database transactions for my university DBMS course. Can you give me a clear breakdown of the ACID properties? Please define what ACID stands for, explain each of the four individual properties in detail, provide a real-world banking example showing why ACID matters, and summarize why transaction integrity is critical for relational databases.""",
            "baseline_output": """ACID Properties in Database Transactions
ACID is a set of four properties that ensure database transactions are processed reliably and correctly:
A — Atomicity
C — Consistency
I — Isolation
D — Durability
1. Atomicity
Atomicity means a transaction is treated as a single, indivisible unit. Either all operations succeed or none of them are permanently applied.
For example, when transferring $500 from Account A to Account B, both the withdrawal and deposit must succeed. If the deposit fails, the withdrawal must also be rolled back.
2. Consistency
Consistency ensures that a transaction takes the database from one valid state to another valid state, maintaining all defined rules and constraints.
For example, if a banking database requires an account balance to satisfy certain constraints, a completed transaction must not leave the database in an invalid state.
3. Isolation
Isolation ensures that concurrent transactions do not improperly interfere with one another. Each transaction should behave as though it is executing independently, according to the database's isolation level.
For example, two simultaneous transfers should not incorrectly read or modify an intermediate account balance.
4. Durability
Durability means that once a transaction is successfully committed, its changes remain stored even if the system subsequently crashes or loses power.
Banking Example
Suppose a customer transfers $500 from Account A to Account B:
$500 is deducted from A.
$500 is added to B.
The transaction commits.
Atomicity prevents only one side of the transfer from occurring. Consistency preserves database rules, Isolation prevents concurrent transactions from causing incorrect results, and Durability ensures the completed transfer remains recorded after a system failure.
Why Transaction Integrity Matters
ACID properties are critical because relational databases often store financial, customer, inventory, and other important data. Without transaction integrity, system failures or concurrent operations could produce missing, duplicated, or inconsistent data. ACID therefore provides the foundation for reliable, predictable, and trustworthy database transactions.""",
            "optimized_prompt": """For a DBMS course, explain the ACID properties in database systems. Address:
1. Meaning of the ACID acronym.
2. Explanation of each property (Atomicity, Consistency, Isolation, Durability).
3. One real-world application example (e.g., bank transfer).""",
            "optimized_output": """ACID Properties in Database Systems
1. Meaning of ACID
ACID stands for:
A — Atomicity
C — Consistency
I — Isolation
D — Durability
These four properties help ensure that database transactions are reliable and maintain data integrity.
2. Explanation of Each Property
Atomicity:
A transaction is treated as one complete unit. Either all operations are completed successfully or none of them are applied. If one operation fails, the database rolls back the entire transaction.
Consistency:
A transaction must move the database from one valid state to another valid state, while maintaining constraints, rules, and relationships defined by the database.
Isolation:
Multiple transactions can execute concurrently without improperly interfering with each other. Each transaction should produce results consistent with the database's specified isolation behavior.
Durability:
Once a transaction has been successfully committed, its changes are permanently stored and should survive system crashes or power failures.
3. Real-World Example: Bank Transfer
Consider transferring $500 from Account A to Account B. The database must deduct $500 from A and add $500 to B.
Atomicity: Both operations succeed, or both are rolled back.
Consistency: Account balances and database constraints remain valid.
Isolation: Simultaneous transactions do not produce incorrect intermediate results.
Durability: Once the transfer is committed, it remains recorded even after a system failure.
Thus, ACID properties are essential for maintaining accurate, reliable, and consistent data, particularly in systems such as banking where transaction errors can have serious consequences.
Pair 4.5"""
        },
        {
            "baseline_prompt": """I will be taking a university Cybersecurity course and I need help understanding asymmetric encryption. Can you please explain Public Key Cryptography? Make sure to explain the difference between public and private keys, describe how key pairs work together during encryption and decryption, provide a real-world scenario like HTTPS, and state two key advantages over symmetric encryption.""",
            "baseline_output": """Public Key Cryptography (Asymmetric Encryption)
Public Key Cryptography, also called asymmetric encryption, is a cryptographic method that uses a mathematically related key pair: a public key and a private key. Unlike symmetric encryption, it does not require both parties to share the same secret key beforehand.
1. Public vs. Private Keys
Public key: Can be openly distributed. It is used to encrypt information for the key owner or, depending on the cryptographic scheme, to verify digital signatures.
Private key: Must be kept secret by its owner. It is used to decrypt information encrypted to the corresponding public key or to create digital signatures.
The two keys are mathematically related, but knowing the public key should not make it practically feasible to derive the private key.
2. How Key Pairs Work
For encryption, suppose Alice wants to send Bob a confidential message:
Alice obtains Bob's public key.
Alice encrypts the message using Bob's public key.
Bob receives the encrypted message.
Bob uses his corresponding private key to decrypt it.
This provides confidentiality because only Bob should possess the private key.
3. Real-World Example: HTTPS
HTTPS uses public-key cryptography as part of TLS. A website presents a certificate containing its public-key information, which helps the browser authenticate the server and establish cryptographic session keys. The actual web traffic is then typically protected using efficient symmetric encryption.
4. Two Key Advantages
No pre-shared secret: Parties can establish secure communication without first exchanging a secret key over an insecure channel.
Digital signatures: Public-key cryptography supports authentication and integrity through digital signatures.
Key distinction: Symmetric encryption uses one shared secret key, while asymmetric cryptography uses a public/private key pair.""",
            "optimized_prompt": """For a university Cybersecurity course, explain Public Key Cryptography covering:
1. Definition and key concept (Public vs. Private Key).
2. How key pairs perform encryption and decryption.
3. One practical application (e.g., HTTPS/TLS).
4. Two advantages over symmetric encryption.""",
            "optimized_output": """Public Key Cryptography
1. Definition and Key Concept
Public Key Cryptography, or asymmetric cryptography, is a cryptographic system that uses two mathematically related keys:
Public Key: Can be openly shared and is used for encryption or signature verification.
Private Key: Must be kept secret and is used for decryption or creating digital signatures.
Unlike symmetric cryptography, the same secret key is not shared between communicating parties.
2. Encryption and Decryption
For confidentiality, the key pair works as follows:
The sender obtains the recipient's public key.
The sender encrypts the message using the recipient's public key.
The recipient receives the encrypted message.
The recipient uses the corresponding private key to decrypt it.
Thus, information encrypted with the recipient's public key can generally be decrypted only with the corresponding private key.
3. Practical Application: HTTPS/TLS
HTTPS uses public-key cryptography through TLS to authenticate servers and establish secure connections. A website provides a certificate containing its public-key information, allowing the browser to verify the server's identity and establish cryptographic session keys; subsequent data transfer is typically protected using faster symmetric encryption.
4. Two Advantages Over Symmetric Encryption
No pre-shared secret required: Two parties can establish secure communication without first exchanging a secret key.
Digital signatures: Asymmetric cryptography supports authentication, integrity, and non-repudiation through digital signatures.
In summary: Symmetric encryption uses one shared secret key, while public-key cryptography uses a public/private key pair."""
        },
    ],
    "Research Paper Summarization": [
        {
            "baseline_prompt": """I am currently writing a literature review for my university research project and I need to summarize an academic paper. Can you please read the attached paper text and give me a clear summary of it? I need you to explain the core research problem the paper focuses on, the overall methodology the authors used, their main findings, and the limitations of the study so that I can properly reference it in my review.""",
            "baseline_output": """I reviewed the attached paper. The paper is a 2024 Heliyon study on healthcare access among marginalized women in Bangladesh and the design of a Bangla 24/7 voice-bot service.
1. Core Research Problem
The paper addresses the limited access to healthcare experienced by marginalized women in Bangladesh, particularly for menstrual and gynecological health. The authors identify barriers including poverty, low literacy, limited awareness, cultural taboos, misconceptions, and hesitation to seek medical assistance. They also note a research gap: relatively little work has focused on healthcare solutions that account for the socioeconomic and cultural circumstances of marginalized women.
The study therefore asks three main questions: what barriers marginalized women face, how technology could improve healthcare access, and whether a 24/7 voice-bot service could facilitate that access.
2. Methodology
The researchers used a mixed-method, field-based approach. They conducted research with marginalized women living in Bangladeshi slum communities, particularly Korail, and also collected information from more privileged women to compare differences in healthcare access and experiences. The analysis examined social, economic, cultural, and healthcare-related factors.
Based on the findings, the researchers designed and implemented a Bangla-language 24/7 voice-bot prototype. The system uses speech recognition, fuzzy string matching, a prepared dataset of 408 Bangla questions and answers, and text-to-speech functionality.
For prototype evaluation, they manually tested the system using 100 questions.
3. Main Findings
The study found substantial healthcare disparities between marginalized and privileged women. Poverty, low literacy, financial constraints, limited awareness, inadequate sanitation, and social/cultural barriers significantly restrict marginalized women's ability to obtain healthcare.
The authors conclude that technology has potential to reduce some of these barriers, particularly because mobile phones are relatively accessible and a voice interface can reduce literacy requirements. Their prototype was intended to provide accessible primary guidance for menstrual and gynecological concerns.
However, the prototype's performance was still limited: it correctly answered 76 out of 100 test questions, meaning it produced inaccurate responses in 24% of cases. The main difficulty was matching queries when they contained fewer than three words overlapping with the prepared dataset.
Overall, the authors argue that a 24/7 voice-bot has significant potential, but it should be regarded as a developing healthcare-access tool rather than a complete replacement for professional medical care.
4. Limitations
The most important limitation is limited representativeness. The research focused on one urban slum, Korail, so the findings may not reflect women living in rural, remote, or other socioeconomic environments. The authors also could not reach a larger population of poor women.
Other limitations include sample-size constraints, potential social-desirability and self-reporting bias, and limited data-collection time.
The voice-bot itself also requires improvement because its 76% accuracy is insufficient for highly reliable healthcare guidance. In addition, the authors identify concerns surrounding data privacy, informed consent, healthcare regulation, accessibility, and legal compliance if such a system were deployed at scale.
Literature Review–Ready Summary
The study by Puja et al. (2024) investigates barriers to healthcare access among marginalized women in Bangladesh and explores whether technology can help address these inequalities. Using field research and mixed-method analysis, the authors identify poverty, low literacy, financial limitations, limited awareness, and cultural stigma as major barriers. They subsequently developed a Bangla 24/7 voice-bot providing primary guidance on menstrual and gynecological concerns. Although the prototype demonstrated potential, correctly answering 76% of 100 test questions, its limited accuracy and the study's restricted sample reduce the generalizability of the findings. The authors therefore recommend broader studies involving larger and more geographically diverse populations and further development of the voice-bot system.""",
            "optimized_prompt": """For a university literature review, summarize the attached research paper text using bullet points covering:
1. Core research problem addressed.
2. Methodology used.
3. Key findings.
4. Study limitations.""",
            "optimized_output": """Core research problem
The paper investigates barriers to healthcare access among marginalized women in Bangladesh, particularly regarding menstrual and gynecological healthcare.
It focuses on socioeconomic, cultural, regional, and educational barriers such as poverty, low literacy, limited awareness, misconceptions, stigma, and affordability.
The authors also examine whether technology can improve access and propose a 24/7 Bangla voice-bot for providing basic healthcare guidance.
Methodology used
The researchers conducted field research and mixed-method analysis involving marginalized women living in slum areas of Bangladesh.
Data were also collected from privileged women to compare healthcare access and experiences between the two groups.
Based on the findings, they designed a 24/7 Bangla-language voice-bot prototype intended to provide primary guidance on menstruation and feminine health.
The prototype was formally evaluated using 100 test questions.
Key findings
Marginalized women face significant healthcare barriers associated with poverty, low literacy, affordability, cultural stigma, misconceptions, and limited awareness of available services.
The study found that technology, particularly voice-based services, could help reduce some access barriers for women who may have limited literacy or primarily use basic mobile phones.
The voice-bot correctly answered 76 of 100 test questions, indicating potential but also significant room for improvement.
The authors conclude that technology can contribute to reducing healthcare disparities, but it cannot by itself eliminate the underlying socioeconomic and cultural barriers.
Study limitations
The research focused primarily on marginalized women in the Korail slum, limiting how broadly the findings can be generalized to other populations or regions.
The authors report limitations involving sample size, self-reporting/social-desirability bias, and limited data-collection time.
The voice-bot's 76% accuracy indicates that its responses were not sufficiently reliable for all healthcare queries.
The paper also identifies broader concerns for future implementation, including privacy, informed consent, regulation, accessibility, and legal compliance.
Pair 5.2"""
        },
        {
            "baseline_prompt": """I am currently writing a literature review for my university research project on Green AI and sustainable computing, and I need to summarize an academic paper. Can you please read the attached paper text and give me a clear summary of it? I need you to explain the core research problem the paper focuses on, the overall experimental methodology the authors used, their key quantitative findings, and the limitations of the study so that I can properly reference it in my review.""",
            "baseline_output": """Absolutely. I read the attached paper "Green AI" by Roy Schwartz, Jesse Dodge, Noah A. Smith, and Oren Etzioni (2019). It is particularly relevant to your literature review because it frames AI sustainability not simply as reducing carbon emissions, but as changing how AI research evaluates computational efficiency alongside accuracy.
1. Core research problem
The paper addresses the rapid growth in the computational cost of deep-learning research and the resulting environmental, economic, and accessibility problems.
The authors highlight that the amount of computation used to train state-of-the-art deep-learning models increased by approximately 300,000× between 2012 and 2018, with computation doubling every few months. This growth produces a substantial carbon footprint and makes AI research increasingly expensive.
The central problem is that the AI research community primarily evaluates models according to accuracy or state-of-the-art performance, while largely ignoring the computational resources required to achieve that performance. The authors describe this approach as "Red AI."
They therefore propose "Green AI": AI research that considers computational efficiency as an important research outcome alongside accuracy. The goal is to obtain strong results while requiring less computation, thereby reducing environmental and financial costs and making AI research more accessible.
In simple terms
The paper asks:
Why should an AI model be considered successful only because it achieves higher accuracy if achieving that accuracy requires dramatically more computation, money, and energy?
2. Overall experimental/methodological approach
An important point for your literature review is that this is primarily a position paper with empirical analysis, rather than a conventional experimental study proposing and testing a new machine-learning algorithm.
The authors use several forms of evidence:
A. Analysis of AI research papers
They sampled 60 papers from three major AI conferences:
ACL
NeurIPS
CVPR
For each paper, they examined whether the main contribution focused on:
accuracy/performance,
efficiency,
both, or
something else.
The results were used to demonstrate the dominance of accuracy-oriented research.
B. Analysis of computational costs
The authors identify three major sources of computational cost:
E — cost of processing one example
D — size of the training dataset
H — number of hyperparameter/model-development experiments
They express the approximate total cost of producing an AI result as:
Cost(R) ∝ E × D × H
This is presented as a simplified model rather than a complete cost equation.
C. Comparison of existing models
They examine existing deep-learning models and compare their computational requirements with their performance. In particular, they use FPO (floating-point operations) as a hardware-independent proxy for computational work.
They compare models such as AlexNet, ResNet, ResNeXt, DPN, and SENet using their FPO requirements and ImageNet accuracy. They also compare different sizes of ResNet.
D. Evaluation of possible efficiency metrics
The authors discuss several possible ways of measuring efficiency:
carbon emissions,
electricity consumption,
elapsed running time,
number of parameters,
FPO.
They ultimately recommend FPO because it is relatively hardware-independent and provides an estimate of the computational work performed by a model.
3. Key quantitative findings
These are probably the most useful numbers to include in your literature review.
These examples demonstrate that increasing model size, training data, and experimentation can produce substantial computational costs.
Diminishing returns
One of the paper's most important findings for Green AI is that additional computation does not produce proportional improvements in performance.
For example, when comparing ResNet and ResNeXt, an approximately 35% increase in FPO resulted in only a 0.5% improvement in top-1 ImageNet accuracy.
The authors therefore argue that simply increasing computational resources is becoming increasingly inefficient: models may continue improving, but the performance gain per unit of computation decreases.
4. The paper's proposed Green AI solution
The authors propose that AI research should report efficiency alongside accuracy.
Their preferred metric is FPO — floating-point operations. The reasoning is that FPO:
estimates the amount of computational work performed,
is relatively independent of the hardware used,
is correlated with energy consumption,
allows more meaningful comparisons between models.
They also recommend reporting the computational budget/accuracy relationship, rather than reporting only the single best result obtained after extensive experimentation. This would allow researchers to understand how much computation was required to reach a particular performance level.
The authors further encourage:
greater emphasis on data-efficient learning,
efficient training,
efficient inference,
reporting hyperparameter searches,
early stopping of clearly underperforming experiments,
sharing pretrained models to avoid unnecessary retraining.
5. Limitations of the study
The paper itself identifies several limitations that are important to acknowledge.
1. FPO is not a direct measurement of carbon emissions
The authors do not claim that FPO directly measures environmental impact. Carbon emissions depend heavily on the electricity infrastructure and energy sources at a particular location, making direct carbon measurements difficult to compare across laboratories.
Therefore, FPO is better understood as a proxy for computational work, rather than a complete sustainability metric.
2. FPO ignores memory consumption
FPO focuses primarily on computational work and electricity consumption but does not capture memory requirements. Large memory requirements can create additional energy and monetary costs.
3. Implementation efficiency is not captured well
Two implementations of the same model can perform very different amounts of computational work. Therefore, FPO can depend on how a model is implemented, not only on its conceptual architecture.
4. The cost equation is simplified
The proposed:
Cost(R) ∝ E × D × H
does not account for every factor affecting computational cost. For example, the authors explicitly note that it ignores the number of training epochs and that different hyperparameter configurations can have different processing costs.
5. Limited empirical sample
The conference analysis is based on only 60 papers, so it provides evidence of a research trend rather than a comprehensive statistical analysis of the entire AI literature.
6. Position-paper nature
The paper is fundamentally an advocacy/position paper. Its main contribution is proposing a research philosophy and evaluation framework rather than conducting a controlled experiment demonstrating that Green AI practices universally reduce real-world carbon emissions.
This distinction is important when you cite it: it is strongest as a conceptual foundation for Green AI and efficiency-aware AI evaluation, rather than as definitive experimental evidence about carbon reduction.
6. Overall contribution to Green AI literature
The paper's major contribution is the introduction and formalization of the Green AI perspective. Rather than treating computational efficiency as merely an engineering constraint, Schwartz et al. argue that efficiency should become a first-class research metric, alongside accuracy.
The paper establishes three important ideas:
1. AI progress has become increasingly computationally expensive.
The enormous growth in training computation creates environmental and economic costs.
2. More computation produces diminishing performance returns.
Increasing model size, data, and experimentation can improve performance, but increasingly large computational investments are required for relatively small gains.
3. AI research should explicitly reward efficiency.
The authors propose reporting computational cost, particularly FPO, and recognizing efficient models as meaningful scientific contributions.
A literature-review-ready synthesis
You could characterize the paper in your literature review like this:
Schwartz et al. (2019) introduced the Green AI perspective, arguing that the rapid growth of computational requirements in deep-learning research creates significant environmental, economic, and accessibility concerns. Through an analysis of 60 papers from ACL, NeurIPS, and CVPR, the authors showed that AI research predominantly emphasizes accuracy rather than computational efficiency. They further analyzed existing models and demonstrated diminishing performance returns as computational requirements increase; for example, a roughly 35% increase in floating-point operations between ResNet and ResNeXt produced only a 0.5% improvement in ImageNet top-1 accuracy. To promote sustainable AI research, the authors proposed reporting computational efficiency alongside accuracy and recommended floating-point operations (FPO) as a hardware-independent measure of computational work. However, FPO does not directly measure carbon emissions and does not fully account for factors such as memory consumption and implementation efficiency. As a position paper, the study provides an influential conceptual framework for Green AI rather than a controlled empirical assessment of actual carbon reductions.
Bottom line: This paper is best used in your review as a foundational paper establishing why AI needs to consider computational efficiency and sustainability, not just accuracy. It also provides a useful bridge between Green AI and the broader field of sustainable computing.""",
            "optimized_prompt": """For a university literature review on Green AI, summarize the attached research paper text using bullet points covering:
1. Core research problem addressed.
2. Experimental methodology used.
3. Key quantitative findings.
4. Study limitations.""",
            "optimized_output": """1. Core research problem addressed
The paper addresses the rapid increase in computational requirements for deep-learning research and its resulting environmental, economic, and accessibility costs.
The authors report that the computation used to train deep-learning models increased by approximately 300,000× from 2012 to 2018, with computation doubling every few months.
The main concern is that AI research tends to prioritize accuracy and state-of-the-art performance while giving comparatively little attention to computational efficiency.
The authors refer to this computationally intensive approach as "Red AI" and propose "Green AI", where efficiency is treated as an evaluation criterion alongside accuracy.
They identify three major sources of computational cost:
Cost of processing each example/model computation (E)
Size of the training dataset (D)
Number of hyperparameter/model-development experiments (H)
They express the approximate cost of generating an AI result as Cost(R) ∝ E × D × H.
2. Experimental methodology used
The paper is primarily a position paper supported by empirical analysis, rather than a controlled experimental study.
The authors analyzed 60 papers from three major AI conferences:
ACL
NeurIPS
CVPR
Each paper was classified according to whether its primary contribution focused on:
accuracy/performance,
efficiency,
both, or
other contributions.
The authors also examined computational requirements of existing deep-learning models and compared computational work with model performance.
They evaluated several possible efficiency measures, including:
carbon emissions,
electricity consumption,
elapsed time,
number of parameters, and
floating-point operations (FPO).
They recommend FPO as a practical efficiency metric because it estimates computational work while being relatively independent of the hardware used.
Existing computer-vision models, including AlexNet, ResNet, ResNeXt, DPN, and SENet, were compared using FPO and ImageNet performance. Different sizes of ResNet were also compared.
3. Key quantitative findings
300,000× increase in computation used to train deep-learning models between 2012 and 2018.
Computation used for AI research was increasing at a rate of approximately doubling every few months.
Among the 60 sampled conference papers:
90% of ACL papers primarily targeted accuracy.
80% of NeurIPS papers primarily targeted accuracy.
75% of CVPR papers primarily targeted accuracy.
Only 10% of ACL and 20% of CVPR papers emphasized efficiency.
BERT-large was trained using 64 TPU chips for four days.
Grover was trained using 256 TPU chips for two weeks, with an estimated cost of approximately $25,000.
XLNet was trained using 512 TPU chips for 2.5 days.
A neural architecture search experiment trained more than 12,800 neural networks, while another study evaluated 1,500 hyperparameter assignments.
In the comparison between ResNet and ResNeXt, an approximately 35% increase in FPO produced only a 0.5% improvement in ImageNet top-1 accuracy.
These results illustrate the paper's central argument that increasing computational resources often produces diminishing returns in model performance.
4. Study limitations
FPO is not a direct measurement of carbon emissions. Actual carbon emissions depend strongly on the electricity infrastructure and energy sources at the location where computation occurs.
FPO does not capture memory consumption, even though memory requirements can contribute additional energy and monetary costs.
Computational work can depend on the specific implementation of a model; two implementations of the same model may require different amounts of computation.
The proposed E × D × H cost model is simplified and does not include every factor affecting computational cost, such as the number of training epochs.
The conference analysis was based on a relatively small sample of 60 papers, so it demonstrates a trend rather than providing a comprehensive analysis of all AI research.
The paper does not experimentally demonstrate actual reductions in carbon emissions resulting from Green AI practices. Its primary contribution is proposing a framework for making computational efficiency a more important criterion in AI research.
The authors themselves acknowledge that Green AI should be viewed as a valuable option rather than an exclusive replacement for Red AI, since computationally intensive research can still produce valuable scientific contributions.
Pair 5.3"""
        },
        {
            "baseline_prompt": """I have to present a research paper breakdown for my university AI seminar class. Could you please read the provided paper text on Convolutional Neural Networks and give me a complete summary? I need to understand what gap in literature the authors are addressing, what neural network model architecture they proposed, what empirical benchmarks/datasets they evaluated on, and what weaknesses remain in their approach.""",
            "baseline_output": """I reviewed the provided paper "Convolutional Neural Network (CNN): The Architecture and Applications" by Joshua Ayobami Ayeni (2022). One important point for your seminar is that this is a review article, not a paper proposing and experimentally validating a new CNN architecture. Therefore, the "research gap," architecture, and benchmarks should be presented accordingly.
1. Literature gap addressed
The paper focuses on providing a review and explanation of CNN architecture, evolution, concepts, and applications, particularly for digital images and computer vision.
Rather than identifying a narrow unresolved technical problem, the authors address the need to understand how CNNs are structured and why they are effective for visual-data processing.
The paper brings together discussions of:
CNN architecture and its fundamental layers.
How CNNs learn spatial feature hierarchies.
The development and use of CNNs in computer vision.
Applications in medical imaging, face recognition, drug discovery, NLP, and speech processing.
The paper therefore fills more of an educational/review gap than an experimental research gap: it synthesizes CNN concepts and applications for readers seeking an overview of the technology.
2. CNN architecture discussed
The paper does not propose a novel neural-network architecture. Instead, it explains the standard CNN architecture and its principal components.
Overall structure
A CNN consists of an input layer, hidden layers, and an output layer.
The hidden portion can contain many layers, with successive layers learning increasingly complex features.
The paper identifies four major CNN components:
Convolutional layer
ReLU activation layer
Pooling layer
Fully connected layer
Convolutional layer
Uses learnable kernels/filters that scan local regions of an image.
Each filter operates over a receptive field and performs mathematical operations to generate feature maps.
Early convolutional layers detect relatively simple patterns such as lines and curves, while deeper layers can identify more complex structures such as faces and objects.
ReLU layer
Applies the Rectified Linear Unit activation function.
Negative input values are converted to zero, while positive values are retained.
The paper explains that ReLU became particularly influential in CNN-based image processing following AlexNet's success on ImageNet.
Pooling layer
Reduces the spatial dimensions of feature maps through downsampling.
Common approaches include:
Max pooling
Average pooling
The paper notes that a common pooling configuration is a 2×2 filter with a stride of 2, reducing the feature-map dimensions by a factor of two.
Pooling can make representations more robust to small changes in feature location, providing a degree of local translation invariance.
Fully connected layer
The final convolutional/pooling representation is converted into a one-dimensional vector.
Fully connected layers use learned weights to map extracted high-level features to the final classification categories.
Architecture flow for your presentation:
Input image → Convolution → ReLU → Pooling → Fully Connected Layer → Classification Output
This is a conceptual representation of the architecture described in the review, not a newly proposed architecture by Ayeni.
3. Empirical benchmarks and datasets
This is another important distinction for your seminar:
The paper does not conduct a new experimental benchmark or train a proposed CNN on a dataset.
Consequently, it does not report a new CNN accuracy, F1-score, precision, recall, or similar quantitative benchmark.
Instead, it discusses applications and cites previous research demonstrating CNN performance.
Examples of datasets/data types and applications mentioned include:
ImageNet — discussed in relation to AlexNet and the emergence of ReLU in large-scale image processing.
MRI images — discussed for medical-image analysis and disease/tumor classification.
X-ray images — discussed for identifying abnormalities such as tumors and broken bones.
CT scans and mammograms — discussed in relation to cancer diagnosis.
Medical imaging research cited by the paper includes work on brain tumors, disease diagnosis, and other medical conditions.
CNN applications in NLP include sentiment analysis, spam detection, and topic categorization.
So, for your seminar, you should not describe these as experiments performed by Ayeni. They are examples and previous studies reviewed by the author.
4. Main contributions and conclusions
CNNs automatically learn hierarchical spatial features from visual data through multiple processing stages.
CNNs have become a dominant approach for:
Computer vision
Image classification
Image segmentation
Object detection
Face recognition
Medical imaging
Image reconstruction
The review also highlights applications beyond traditional computer vision, including:
Drug discovery
NLP
Speech recognition.
The overall conclusion is that CNNs have become an established deep-learning technique with broad potential across research and practical applications.
5. Weaknesses and limitations
The paper has several important limitations that you can mention during your presentation:
No novel CNN architecture is proposed. The article reviews existing CNN components and applications rather than introducing a new model.
No original experimental evaluation is conducted. Therefore, there is no controlled comparison of a proposed CNN against competing architectures.
No systematic benchmark table reporting standardized accuracy, computational cost, training time, or other metrics is provided.
The discussion of applications is broad but sometimes descriptive rather than quantitatively comparative.
The paper relies extensively on secondary sources, online educational materials, and previously published studies, rather than generating new experimental evidence. The reference list demonstrates this mixture of sources.
The paper discusses several limitations of CNN components themselves. For example:
ReLU can produce "dead neurons" when neurons consistently receive negative inputs.
Pooling can sometimes reduce overall CNN performance because information is discarded during downsampling.
Because the paper is a 2022 review, it does not provide an up-to-date evaluation of many later CNN developments or newer architectures.
Key takeaway for your seminar
Ayeni (2022) is best characterized as a review of CNN architecture and applications rather than a novel CNN research paper. The article explains how convolution, ReLU, pooling, and fully connected layers work together to extract hierarchical features and perform classification. It reviews CNN applications across computer vision, medical imaging, drug discovery, NLP, and speech processing, but does not introduce a new architecture or conduct original dataset-based experiments. Its main weakness is therefore the lack of original empirical validation and quantitative benchmarking.""",
            "optimized_prompt": """For an academic AI seminar summary, analyze the attached Computer Vision paper using bullet points covering:
1. Specific research gap addressed.
2. Proposed model architecture and methodology.
3. Evaluation datasets and benchmark metrics.
4. Identified limitations or weaknesses.""",
            "optimized_output": """I analyzed the attached paper "Convolutional Neural Network (CNN): The Architecture and Applications" by Joshua Ayobami Ayeni (2022). A key clarification for an academic seminar is that this is a review article, not a paper proposing and experimentally validating a new computer-vision model.
1. Specific research gap addressed
The paper addresses the need for a consolidated understanding of CNN architecture, underlying concepts, evolution, and applications in digital-image processing and computer vision.
It does not identify a narrowly defined unresolved computer-vision problem such as object-detection accuracy, segmentation, or domain adaptation.
Instead, the review brings together existing knowledge about how CNNs learn spatial hierarchies of visual features and why they have become dominant in computer vision.
The paper also connects CNN technology to a broad range of applications, including:
Image classification
Object detection
Image segmentation
Face recognition
Medical imaging
Drug discovery
NLP and speech processing.
Seminar interpretation: The paper's contribution is primarily knowledge synthesis and explanation, rather than filling a specific algorithmic performance gap.
2. Proposed model architecture and methodology
There is no newly proposed CNN architecture. The paper explains the conventional CNN architecture and its components.
The CNN is described as consisting of:
Input layer
Convolutional layers
ReLU activation
Pooling/downsampling layers
Fully connected layer
Output/classification layer.
Convolution:
Learnable kernels/filters scan local regions called receptive fields.
The filters perform dot-product operations to generate feature maps.
Successive layers learn increasingly complex representations—from basic patterns such as lines and curves to higher-level objects.
ReLU:
Introduces non-linearity.
Negative values are converted to zero while positive values pass through.
The paper discusses its importance in modern CNNs and associates its widespread adoption with the success of AlexNet on ImageNet.
Pooling:
Reduces feature-map dimensions and computational requirements.
Max pooling and average pooling are discussed.
A commonly described configuration is a 2×2 pooling region with stride 2, reducing feature-map dimensions by a factor of two.
Fully connected layer:
Converts the extracted feature representation into class predictions.
The final output dimension corresponds to the number of classification categories.
Overall methodology: The author performs a literature-based review, drawing on previous CNN studies and explanatory sources rather than training a new model or conducting a controlled experiment.
3. Evaluation datasets and benchmark metrics
No original experimental dataset or benchmark evaluation is reported by the paper.
Therefore, the paper does not provide original:
Accuracy
Precision
Recall
F1-score
mAP
IoU
Training/inference-time comparisons.
ImageNet is discussed as an important benchmark in the historical development of CNNs, particularly in relation to AlexNet and ReLU. However, the author does not report a new ImageNet experiment.
The paper reviews CNN applications involving:
MRI
X-ray
CT scans
Mammograms
Other medical-image datasets.
These datasets/examples come from previously published research cited by the author, rather than experiments conducted in this paper. The references include studies on medical-image classification and disease diagnosis.
Important for presentation: Do not say "the authors evaluated their CNN on ImageNet." A more accurate statement is: "The paper discusses ImageNet and other datasets as examples from prior CNN research."
4. Identified limitations or weaknesses
No novel model: The paper does not introduce a new CNN architecture, optimization technique, or learning algorithm.
No original empirical validation: There is no controlled experiment demonstrating that the reviewed architecture outperforms competing approaches.
No quantitative benchmark comparison: The paper does not provide a systematic table comparing CNN models using standardized performance metrics.
Broad rather than deep coverage: It covers many applications, but individual applications are discussed mainly descriptively rather than through detailed experimental comparisons.
Dependence on secondary sources: The review incorporates a mixture of previous academic research and online/tutorial sources, which limits its strength as a rigorous systematic review.
ReLU limitation: The paper notes that ReLU can produce "dead neurons" because negative inputs are mapped to zero, potentially causing neurons to stop activating.
Pooling limitation: Pooling discards some spatial information and can sometimes decrease CNN performance, despite reducing dimensionality and computational cost.
Limited experimental evidence for real-world claims: Although the paper discusses applications such as medical diagnosis and drug discovery, these claims are based on cited studies rather than experiments performed by the author.
One-sentence seminar takeaway
Ayeni (2022) provides a broad review of conventional CNN architecture and applications, explaining convolution, ReLU, pooling, and fully connected layers, but it does not propose a novel model or conduct original benchmark experiments; consequently, its main weakness is the absence of quantitative empirical validation.
Pair 5.4"""
        },
        {
            "baseline_prompt": """I am gathering papers for my university thesis literature survey on Natural Language Processing and token usage efficiency. Can you summarize the attached paper for me? Please tell me what main research questions the paper investigates, what LLM models or tokenizers were tested in their experiments, what the primary results show regarding token waste, and what recommendations the authors make for future research.""",
            "baseline_output": """I reviewed the attached paper "LLMLingua: Compressing Prompts for Accelerated Inference of Large Language Models" (arXiv:2310.05736v2). The paper is highly relevant to your thesis topic because it studies prompt/token compression as a way to reduce unnecessary token processing and inference cost while preserving LLM performance.
1. Main research questions
Can prompts be substantially shortened without losing the information needed by an LLM to perform the task?
Can token-level prompt compression reduce LLM inference cost while maintaining reasoning, in-context learning (ICL), and contextual-understanding capabilities?
How can a smaller language model be used to identify which tokens are important to a much larger black-box LLM?
How can compression preserve dependencies between tokens, particularly for difficult multi-step reasoning tasks?
The authors also investigate whether the distribution difference between the small compressor model and the target LLM affects compression quality.
The paper's underlying motivation is that long prompts contain information that is not equally useful to the target LLM. Removing low-information or redundant tokens can therefore reduce the number of tokens that the expensive LLM needs to process.
2. LLMs, small models, and tokenization tested
Target LLMs:
GPT-3.5-Turbo-0301
Claude-v1.3
Small language models used for compression:
Alpaca-7B
GPT2-Alpaca
GPT2-Alpaca was trained on the Alpaca dataset and used as a weaker alternative compressor.
Additional model used for analysis:
GPT-4 was used to investigate whether an LLM could reconstruct/recover information from compressed prompts.
Tokenization:
The experiments used tiktoken together with GPT-3.5-Turbo to count tokens.
The authors also identify an important tokenizer-related limitation: the small compressor model and the black-box target LLM may use different tokenizers, potentially causing the prompt length to be underestimated.
3. Primary results regarding token waste/compression
The central result is that very large reductions in prompt tokens are possible while retaining much of the original LLM capability.
The authors evaluate four datasets:
GSM8K — mathematical reasoning
BBH — reasoning and in-context learning
ShareGPT — conversation
Arxiv-March23 — summarization.
On GSM8K, the full-shot prompt contained 2,366 tokens.
LLMLingua achieved approximately:
6× compression under the 1-shot constraint
14× compression under the half-shot constraint
20× compression under the quarter-shot constraint.
On GSM8K, the method actually achieved an Exact Match score of 79.02 under the 1-shot setting, compared with 78.85 for the original full-shot prompt, while using dramatically fewer tokens.
On BBH, the method achieved roughly:
3× compression with the 1-shot constraint
5× compression under the half-shot constraint
7× compression under the quarter-shot constraint.
For contextual tasks:
ShareGPT: approximately 9× acceleration
Arxiv-March23: approximately 3.3× acceleration, while maintaining high BERTScore.
The paper provides a striking example of token reduction: a 2,366-token GSM8K prompt was compressed to 117 tokens in an illustrative example.
Importantly, the authors show that compression can also reduce generated output length, meaning the savings are not limited to input processing.
4. Efficiency and cost results
At a 5× compression ratio, the authors estimate approximately 4× computational-resource savings compared with processing the original prompt directly with the large LLM.
On a V100 GPU, end-to-end latency improved from 8.6 seconds without LLMLingua to:
4.9 s at 2× compression → 1.7× speedup
2.3 s at 5× → 3.3× speedup
1.3 s at 10× → 5.7× speedup.
Estimated GPT-3.5-Turbo inference costs were reduced substantially; for example, on GSM8K the reported cost decreased from $5.2 to $0.5 in the evaluated setting.
5. Recommendations and future research directions
The authors' work suggests several important directions for future research:
Develop better prompt-compression methods that can achieve higher compression ratios without sacrificing reasoning ability.
Improve token-level compression, particularly for complex multi-step reasoning where removing a seemingly unimportant token can destroy an entire reasoning chain.
Address the distribution mismatch between small compressor models and target LLMs. The paper shows that weaker compressor models such as GPT2-Alpaca can perform worse than Alpaca-7B because their learned distributions differ from those of the target LLM.
Develop methods that are less dependent on a particular tokenizer, since differences between the compressor's tokenizer and target LLM tokenizer can lead to inaccurate token-count estimates.
Investigate adaptive compression ratios because the maximum useful compression varies with prompt length, task type, and number of sentences.
Study the trade-off between token savings and performance degradation at extreme compression levels.
The authors specifically observe that performance can drop substantially at approximately 25×–30× compression, particularly on difficult reasoning tasks such as GSM8K.
Key takeaway for your thesis
LLMLingua demonstrates that substantial token waste exists in conventional LLM prompts and that intelligently removing low-information tokens can reduce prompt length by several-fold—up to around 20× in some experiments—while retaining much of the original reasoning and contextual performance. The study therefore provides strong evidence that token-level prompt compression can improve LLM inference efficiency, although extreme compression causes performance degradation and tokenizer/distribution differences remain important challenges.""",
            "optimized_prompt": """For an academic NLP literature survey, summarize the attached paper text using bullet points covering:
1. Primary research questions investigated.
2. Experimental setup and models evaluated.
3. Key findings on token efficiency/waste.
4. Author-recommended future directions.""",
            "optimized_output": """1. Primary research questions investigated
Can prompts be compressed substantially while preserving the information needed by large language models (LLMs)?
Can token-level prompt compression reduce LLM inference computation, latency, and cost without significantly harming task performance?
How can a small language model identify and remove redundant or low-information tokens while preserving dependencies between important tokens?
How does the distribution mismatch between the small compression model and the target LLM affect compression quality?
Can compressed prompts preserve difficult capabilities such as multi-step reasoning and in-context learning (ICL)?
2. Experimental setup and models evaluated
The proposed approach is LLMLingua, a coarse-to-fine prompt-compression framework.
It contains three major components:
Budget Controller — dynamically assigns compression ratios to instructions, demonstrations, and questions.
Iterative Token-Level Prompt Compression (ITPC) — removes less important tokens while considering conditional dependencies between tokens.
Distribution Alignment — reduces the mismatch between the small compression model and the target LLM.
Target LLMs:
GPT-3.5-Turbo-0301
Claude-v1.3
Small compression models:
Alpaca-7B
GPT2-Alpaca
GPT-4 was additionally used to examine whether semantic/reasoning information could be recovered from compressed prompts.
Datasets/tasks:
GSM8K — mathematical reasoning
BBH — language/symbolic reasoning and ICL
ShareGPT — conversational understanding
Arxiv-March23 — summarization.
Evaluation metrics:
Exact Match (EM) for GSM8K and BBH
BLEU, ROUGE, and BERTScore for ShareGPT and Arxiv-March23.
Token counts were measured using tiktoken with GPT-3.5-Turbo.
3. Key findings on token efficiency/waste
LLMLingua achieved substantial prompt-token reduction while generally preserving task performance.
On GSM8K:
Full-shot prompt: 2,366 tokens
Approximately 6× compression under the 1-shot constraint.
Up to 14× and 20× compression under more aggressive constraints, with only modest EM degradation.
On BBH, compression ratios of approximately 3×, 5×, and 7× were achieved under different constraints. Performance decreased as compression became more aggressive, particularly on difficult reasoning tasks.
On ShareGPT and Arxiv-March23, the method achieved approximately 9× and 3.3× acceleration, respectively, while retaining high semantic similarity.
An illustrative example reduced a 2,366-token prompt to 117 tokens, demonstrating the potential magnitude of token savings.
At 5× compression, the authors estimate nearly 4× computational-resource savings.
End-to-end latency on a V100 GPU improved from 8.6 seconds without LLMLingua to 1.3 seconds at 10× compression, corresponding to a 5.7× speedup.
Estimated GPT-3.5-Turbo inference cost on GSM8K fell from $5.2 to $0.5 in the reported comparison.
However, token efficiency has a clear trade-off: at approximately 25×–30× compression, the authors observe substantial performance degradation.
The study also finds that a weaker compressor, GPT2-Alpaca, performs worse than Alpaca-7B because of greater distribution differences from the target LLM.
4. Author-recommended future directions
Develop compression techniques that achieve higher compression ratios without sacrificing reasoning performance.
Improve preservation of token dependencies and multi-step reasoning, since removing individual tokens can sometimes destroy critical reasoning information.
Address the distribution discrepancy between small compression models and target LLMs through better alignment techniques.
Develop methods that account for differences between tokenizers, since tokenizer mismatches can cause prompt-length estimates to be inaccurate.
Investigate adaptive compression levels, because the maximum safe compression ratio depends on prompt length, task type, and sentence structure.
Further study the performance–compression trade-off, especially for complex reasoning tasks where excessive compression causes substantial degradation.
Overall, the paper suggests that future efficient-LLM research should treat token usage as an important computational resource, rather than optimizing model performance without considering the number of tokens processed.
Pair 5.5"""
        },
        {
            "baseline_prompt": """I need to synthesize an empirical software engineering paper to include in my Master's thesis background chapter. Can you read the provided paper text and extract the key information? I need a summary covering the software engineering problem being studied, the research design (such as survey, case study, or repository mining), the statistical results obtained, and any threats to validity mentioned by the authors.""",
            "baseline_output": """I reviewed the attached paper "An Empirical Study on the Code Refactoring Capability of Large Language Models" by Jonathan Cordeiro, Shayan Noei, and Ying Zou. The paper specifically studies whether StarCoder2 can perform code refactoring as effectively as human developers, with particular attention to code-smell reduction, code-quality improvement, and prompt engineering.
1. Software engineering problem being studied
Problem: Automating code refactoring with large language models while improving internal code quality without changing the software's external functionality.
The authors identify a research gap: although LLMs have demonstrated strong code-generation capabilities, there were no systematic studies examining the impact of LLM-generated refactorings on code-quality improvement.
The study specifically investigates whether LLM-generated refactorings can:
outperform developer refactorings,
reduce code smells,
improve code-quality metrics,
preserve functionality, and
be improved through prompt engineering.
Four research questions are investigated:
RQ1: Can LLMs outperform developers in code refactoring?
RQ2: Which types of code smells are most effectively reduced by LLMs or developers?
RQ3: Which refactoring types are most effective for improving code quality?
RQ4: How does prompt engineering affect the quality of LLM-generated refactorings?
2. Research design / methodology
The study uses repository mining combined with controlled empirical experimentation.
Researchers use the 20-MAD dataset, which contains historical development information from 765 Apache projects.
They filter the dataset to Java projects with sufficient development history and ultimately select 30 open-source Java projects.
Projects included in StarCoder2's training dataset are removed to reduce the risk of data leakage.
The final study contains 5,194 refactoring commits from the 30 projects.
The researchers extract code before and after real developer refactorings, then give the same pre-refactoring code to StarCoder2-15B-Instruct and compare the generated refactoring with the developer's actual change.
Refactorings are detected using RefactoringMiner (RMiner). The cited evaluation of the tool reports 99.7% precision and 94.2% recall on the relevant dataset.
DesigniteJava is used for code-smell detection, while Understand is used for code-quality metrics. Unit tests are used to evaluate whether generated refactorings preserve functionality.
Three prompting strategies are evaluated:
Zero-shot — baseline.
One-shot — provides an example of a correct developer refactoring.
Chain-of-thought — provides explicit suggestions and explanations of refactoring types.
3. Statistical and quantitative results
Code-smell reduction:
Developer refactorings reduced code smells by 24.27%.
StarCoder2 reduced code smells by 44.36% among refactorings that passed the unit-test evaluation.
Thus, StarCoder2 achieved a 20.1 percentage-point higher reduction rate in the reported comparison.
A statistical U-test produced p = 0.003, indicating a statistically significant difference in the distributions of code smells across the compared conditions.
Absolute code-smell counts:
Initial unrefactored dataset: 17,429 code smells.
After developer refactoring: 13,199.
For the subset successfully refactored by StarCoder2: 12,213 → 6,795 code smells.
Functional correctness:
StarCoder2 achieved a 28.36% pass@1 unit-test pass rate.
With multiple generated candidates, the average pass rate increased to 57.15% at pass@5.
The authors therefore emphasize comprehensive testing when using LLMs for refactoring.
Prompt engineering:
One-shot prompting achieved a 34.51% unit-test pass rate, a 6.15-percentage-point improvement over zero-shot prompting.
Its code-smell reduction rate was 42.97%, 3.52 percentage points higher than zero-shot prompting.
Zero-shot achieved 28.36% unit-test pass rate and 39.45% code-smell reduction.
Chain-of-thought prompting increased the variety of refactorings, introducing seven additional types not observed with zero-shot prompting.
One-shot prompting generally performed best across measures involving code complexity and modularity.
Nature of refactoring:
StarCoder2 was particularly effective at systematic and repetitive refactorings.
Developers performed better on complex, context-dependent architectural changes, including broken modularization and deficient encapsulation.
The authors therefore view LLMs and developers as having complementary strengths, rather than treating LLMs as complete replacements for developers.
4. Threats to validity
Internal validity
Hardware/software variability: Results could potentially depend on the computing environment. The researchers controlled this by running experiments using consistent hardware and software on the same server.
LLM hallucination: StarCoder2 may generate syntactically or logically incorrect code. Unit tests and inspection were used to identify invalid outputs, but hallucination remains an inherent threat.
Random commit selection: Different sampled commits could produce different results.
Single-commit analysis: Refactorings spanning multiple commits may not be captured, potentially underestimating the complexity or scope of some refactoring activities.
Potential training-data overlap: Although projects in the evaluation were excluded from StarCoder2's known training dataset, similar code patterns could still have appeared in the model's training data.
External validity
The study uses a relatively limited sample of open-source Java projects from Apache, so results may not generalize to:
other programming languages,
proprietary software,
different development environments,
other LLMs or model versions.
The authors explicitly note that results could differ for other versions of StarCoder2 or LLMs from other vendors.
Construct validity
Refactoring quality is primarily assessed using code-smell reduction, code-quality metrics, and unit-test pass rates.
These measures do not fully capture dimensions such as code readability and performance.
Results can also depend on the measurement tools used, including RMiner, DesigniteJava, and Understand.
Thesis-ready synthesis
Cordeiro et al. provide empirical evidence that LLM-based refactoring can substantially reduce code smells and improve several code-quality metrics, but its effectiveness depends strongly on the type of refactoring and prompting strategy. Using 5,194 historical refactoring commits from 30 open-source Java projects, the study found a 44.36% code-smell reduction for StarCoder2 versus 24.27% for developers, with the difference statistically significant at p = 0.003. However, developers remained stronger at context-dependent architectural refactorings, while StarCoder2 was more effective at systematic and repetitive changes. The study's conclusions are constrained by its focus on one LLM, Java open-source projects, selected commits, and quality metrics that do not capture all aspects of software quality.""",
            "optimized_prompt": """For a Master's thesis literature chapter, synthesize the attached Software Engineering paper using bullet points covering:
1. Core software engineering problem studied.
2. Research methodology and data collection design.
3. Key statistical results.
4. Noted threats to validity.""",
            "optimized_output": """1. Core software engineering problem studied
The paper investigates whether Large Language Models (LLMs) can effectively perform automated code refactoring.
More specifically, it examines whether StarCoder2 can generate refactorings that improve software quality while preserving program functionality.
The study focuses on:
Reduction of code smells.
Improvement of code-quality metrics such as complexity, cohesion, coupling, and modularity.
Comparison between LLM-generated refactorings and real developer refactorings.
The effect of different prompt-engineering strategies on LLM refactoring quality.
The authors investigate four research questions:
RQ1: Can LLMs outperform developers in code refactoring?
RQ2: Which code-smell types are most effectively reduced by LLMs and developers?
RQ3: Which refactoring types are most effective for improving code quality?
RQ4: How does prompt engineering affect the quality of LLM-generated refactorings?
2. Research methodology and data collection design
The study uses a combination of repository mining and controlled empirical experimentation.
The researchers begin with the 20-MAD dataset, containing development information from 765 Apache projects.
After filtering, they select 30 open-source Java projects for the final experiment.
Projects known to be included in StarCoder2's training data were excluded to reduce possible data leakage.
The final dataset contains 5,194 historical refactoring commits.
The researchers extract the code before actual developer refactoring and provide the same pre-refactoring code to StarCoder2-15B-Instruct.
LLM-generated refactorings are then compared with the corresponding real developer refactorings.
Tools used include:
RefactoringMiner for identifying refactoring operations.
DesigniteJava for detecting code smells.
Understand for code-quality metrics.
Unit tests for assessing whether generated refactorings preserve functionality.
Three prompting strategies are evaluated:
Zero-shot prompting — baseline.
One-shot prompting — provides an example of a correct refactoring.
Chain-of-thought prompting — provides additional guidance about possible refactoring operations.
Statistical analysis includes a U-test for comparing code-smell distributions and Scott-Knott clustering for comparing performance across approaches.
3. Key statistical results
Code-smell reduction:
Developer refactoring reduced code smells by 24.27%.
StarCoder2 reduced code smells by 44.36% for the successfully generated/test-passing refactorings.
The difference was statistically significant, with p = 0.003 from the U-test.
The initial dataset contained 17,429 code smells.
After developer refactoring: 13,199.
For the StarCoder2 subset that passed unit tests: 12,213 → 6,795.
Prompt engineering results:
One-shot prompting achieved a 34.51% unit-test pass rate.
This was 6.15 percentage points higher than zero-shot prompting.
One-shot prompting achieved a 42.97% code-smell reduction rate, approximately 3.52 percentage points higher than zero-shot.
StarCoder2 was particularly effective at systematic and repetitive refactoring tasks.
Human developers performed more complex, context-dependent changes, including refactorings involving modularity, encapsulation, and class hierarchies.
The results therefore suggest complementary strengths: LLMs can automate repetitive refactoring effectively, while developers remain important for more complex structural decisions.
4. Noted threats to validity
Internal validity
Hardware/software configuration: Results could vary with computational environments. The researchers attempted to control this by using consistent hardware and software configurations.
LLM hallucination: StarCoder2 can generate syntactically or logically incorrect code. Unit testing was used to identify unsuccessful outputs, but hallucination remains a potential threat.
Random commit selection: Different sampled commits could produce different findings.
Single-commit analysis: Refactorings distributed across multiple commits may not be fully captured, potentially limiting the representation of complex refactoring activities.
Training-data overlap: Although projects known to be in StarCoder2's training data were excluded, similar code or patterns could still have occurred in its training corpus.
External validity
The study is restricted to 30 open-source Java projects, primarily from the Apache ecosystem.
Consequently, the findings may not generalize directly to:
Other programming languages.
Proprietary/industrial software.
Other development environments.
Other LLM architectures or model versions.
Construct validity
Refactoring quality is assessed primarily through code-smell reduction, software-quality metrics, and unit-test results.
These measures do not necessarily capture every aspect of software quality, such as readability or runtime performance.
Results may also be influenced by the particular analysis tools used, including RefactoringMiner, DesigniteJava, and Understand.
Overall: The study provides statistically significant evidence that StarCoder2 can reduce code smells more than the historical developer refactorings examined, but the result is conditional on successful, test-passing LLM outputs and should not be interpreted as evidence that LLMs universally outperform developers at software refactoring."""
        },
    ],
}

# ==== CALCULATE ====
results = []

for category, pair_list in data.items():
    for idx, p in enumerate(pair_list, start=1):
        b_in = count_tokens(p["baseline_prompt"])
        b_out = count_tokens(p["baseline_output"])
        o_in = count_tokens(p["optimized_prompt"])
        o_out = count_tokens(p["optimized_output"])

        b_total = b_in + b_out
        o_total = o_in + o_out

        input_waste = b_in - o_in          # Token Waste (input-only inefficiency)
        output_diff = b_out - o_out        # Output token difference
        total_saved = b_total - o_total    # Total tokens saved
        pct_reduction = (total_saved / b_total) * 100 if b_total > 0 else 0

        results.append({
            "Category": category,
            "Pair #": idx,
            "Baseline Input": b_in,
            "Baseline Output": b_out,
            "Baseline Total": b_total,
            "Optimized Input": o_in,
            "Optimized Output": o_out,
            "Optimized Total": o_total,
            "Input Tokens Wasted": input_waste,
            "Output Token Diff": output_diff,
            "Total Tokens Saved": total_saved,
            "Net % Reduction": round(pct_reduction, 2)
        })

# ==== DISPLAY ====
df = pd.DataFrame(results)
print(df.to_string(index=False))

# ==== CATEGORY AVERAGE ====
summary = df.groupby("Category").agg({
    "Baseline Total": "mean",
    "Optimized Total": "mean",
    "Input Tokens Wasted": "mean",
    "Total Tokens Saved": "mean",
    "Net % Reduction": "mean"
}).round(2)
print("\n=== Category Average ===")
print(summary)

# ==== OVERALL AVERAGE (all 5 categories combined) ====
overall = df.agg({
    "Baseline Total": "mean",
    "Optimized Total": "mean",
    "Input Tokens Wasted": "mean",
    "Total Tokens Saved": "mean",
    "Net % Reduction": "mean"
}).round(2)
print("\n=== Overall Average (All Categories) ===")
print(overall)

# ==== SAVE CSV ====
df.to_csv("all_categories_results.csv", index=False)
summary.to_csv("all_categories_summary.csv")
print("\nSaved: all_categories_results.csv, all_categories_summary.csv")
# Out:
# ...
#                     Category  Pair #  Baseline Input  Baseline Output  Baseline Total  Optimized Input  Optimized Output  Optimized Total  Input Tokens Wasted  Output Token Diff  Total Tokens Saved  Net % Reduction
#           Assignment Writing       1              83              260             343               51               271              322                   32                -11                  21             6.12
#           Assignment Writing       2              80              681             761               58               453              511                   22                228                 250            32.85
#           Assignment Writing       3              69               46             115               57                 5               62                   12                 41                  53            46.09
# ...

# %%
# !pip install tiktoken pandas

import tiktoken
import pandas as pd

enc = tiktoken.get_encoding("cl100k_base")

def count_tokens(text):
    return len(enc.encode(text))

data = {
    "Assignment Writing": [
        {
            "baseline_prompt": """I am doing an assignment for my university Environmental Science course and I need help with a question about energy sources. Please write an explanation of around 200 words comparing renewable and non-renewable energy sources. Explain what each one is, give two examples of each, and discuss their main environmental impact. Please make the explanation clear and understandable for a student and make sure that all of the important points are properly explained.""",
            "baseline_output": """Renewable and Non-Renewable Energy Sources
Energy sources can be divided into two main types: renewable and non-renewable. Renewable energy comes from natural resources that are continuously replenished and can be used repeatedly without being permanently depleted. Examples include solar energy, which comes from sunlight, and wind energy, which uses moving air to generate electricity. Renewable energy generally has a lower environmental impact because it produces little or no greenhouse gas emissions during operation. However, renewable energy projects can still affect ecosystems, for example, through land use, habitat disturbance, and changes to landscapes.
Non-renewable energy comes from resources that exist in limited amounts and take millions of years to form, so they cannot be replaced quickly once they are used. Examples include coal and petroleum (oil). These fuels are widely used for electricity, transportation, and industry, but their environmental impacts are significant. Burning coal and oil releases carbon dioxide and other pollutants, contributing to climate change, air pollution, and acid rain. Extracting these fuels can also damage land and water resources through mining, drilling, and oil spills.
Overall, renewable energy is generally more sustainable and environmentally friendly, while non-renewable energy causes greater pollution and resource depletion. Transitioning toward renewable sources can help reduce environmental damage and greenhouse gas emissions.""",
            "optimized_prompt": """For an introductory Environmental Science assignment, compare renewable and non-renewable energy sources in about 200 words. Address the following:
Define renewable and non-renewable energy.
Provide two examples of each type.
Outline the primary environmental impact of each source.""",
            "optimized_output": """Renewable and Non-Renewable Energy Sources
Energy sources are generally classified as renewable or non-renewable based on how quickly they can be naturally replaced. Renewable energy comes from natural resources that are continuously replenished and can be used repeatedly. Examples include solar energy, which uses sunlight to produce electricity or heat, and wind energy, which uses moving air to generate electricity. Renewable energy usually has a lower environmental impact than fossil fuels because it produces little or no greenhouse gas emissions during operation. However, renewable energy projects can still affect the environment through land use, habitat disturbance, and changes to natural landscapes.
Non-renewable energy comes from resources that are finite and take extremely long periods, often millions of years, to form. Once consumed, they cannot be replaced within a human lifetime. Coal and petroleum (oil) are two common examples. The main environmental impact of using these fuels is the release of greenhouse gases, particularly carbon dioxide, which contributes to climate change. Burning coal and oil also produces air pollutants that can harm human health and ecosystems. In addition, mining, drilling, and oil extraction can cause habitat destruction, soil degradation, and water pollution.
Overall, renewable energy is generally more sustainable and has fewer environmental impacts, while non-renewable energy contributes significantly to pollution, climate change, and resource depletion."""
        },
        {
            "baseline_prompt": """I am working on an assignment for my university Data Science class where I have to draft an essay outline about supervised, unsupervised, and reinforcement learning. Can you please write a clear essay outline for me? Make sure to include an introduction section, main body section for each of the three paradigms, and a conclusion section with all relevant details so I can use it to write my paper.""",
            "baseline_output": """Essay Outline: Supervised, Unsupervised, and Reinforcement Learning
1. Introduction
Background: Introduce machine learning as a major area of Artificial Intelligence and Data Science that enables computers to learn patterns from data.
Purpose: Explain that machine learning contains several learning paradigms designed for different types of problems.
Thesis statement: This essay will examine supervised, unsupervised, and reinforcement learning by comparing their learning processes, training data, applications, advantages, and limitations.
Briefly introduce the three paradigms.
2. Supervised Learning
2.1 Definition
Explain that supervised learning trains models using labelled datasets containing inputs and known target outputs.
2.2 How It Works
Training data is provided to the model.
The model learns relationships between inputs and outputs.
The trained model makes predictions on new, unseen data.
2.3 Common Tasks
Classification: Predicting categories, such as spam or non-spam emails.
Regression: Predicting numerical values, such as house prices.
2.4 Advantages and Limitations
Advantages: High predictive accuracy with suitable labelled data; performance can be evaluated using known targets.
Limitations: Requires large amounts of labelled data; data labelling can be expensive and time-consuming.
3. Unsupervised Learning
3.1 Definition
Explain that unsupervised learning works with unlabelled data and discovers hidden patterns or structures.
3.2 How It Works
The algorithm analyzes the available data without predefined target outputs.
It identifies similarities, groups, relationships, or unusual observations.
3.3 Common Applications
Customer segmentation using clustering.
Anomaly detection in financial transactions.
Dimensionality reduction for complex datasets.
3.4 Advantages and Limitations
Advantages: Does not require labelled data; useful for discovering previously unknown patterns.
Limitations: Results can be difficult to interpret; evaluating the quality of discovered patterns can be challenging.
4. Reinforcement Learning
4.1 Definition
Explain reinforcement learning as a paradigm in which an agent learns through interaction with an environment.
4.2 How It Works
The agent observes the current state.
It takes an action.
The environment provides a reward or penalty.
The agent learns a strategy, or policy, that aims to maximize cumulative reward over time.
4.3 Real-World Applications
Robotics and autonomous systems.
Game-playing systems.
Resource allocation and recommendation optimization.
4.4 Advantages and Limitations
Advantages: Can learn effective strategies through experience; does not always require labelled training examples.
Limitations: Training can require substantial time and computational resources; poorly designed reward functions can produce undesirable behaviour.
5. Comparison of the Three Paradigms
Supervised: Learns from labelled input-output examples.
Unsupervised: Finds patterns in unlabelled data.
Reinforcement: Learns through actions, feedback, and rewards.
Compare their training processes, data requirements, objectives, and typical applications.
Discuss how the choice of paradigm depends on the problem and available data.
6. Conclusion
Summarize the key characteristics of all three learning paradigms.
Emphasize that each approach is appropriate for different types of Data Science problems.
Reinforce the importance of selecting a learning paradigm based on the available data, desired outcome, and problem requirements.
Conclude by noting that understanding these paradigms is essential for applying machine learning effectively in real-world situations.""",
            "optimized_prompt": """For a university Data Science assignment, create a structured essay outline on Machine Learning Paradigms (Supervised, Unsupervised, Reinforcement Learning). Ensure the output includes:
Introduction section with thesis statement.
Three main body sections with key sub-topics per paradigm.
Brief conclusion section summary.""",
            "optimized_output": """Essay Outline: Machine Learning Paradigms
1. Introduction
Background: Define Machine Learning (ML) as a branch of Artificial Intelligence that enables systems to learn patterns from data and improve performance without being explicitly programmed for every task.
Three paradigms: Introduce supervised, unsupervised, and reinforcement learning as major approaches to machine learning.
Importance: Explain their relevance to areas such as prediction, pattern discovery, automation, and decision-making.
Thesis Statement: This essay examines supervised, unsupervised, and reinforcement learning by comparing their learning processes, data requirements, applications, advantages, and limitations.
2. Supervised Learning
Key Sub-topics
Definition: Learning from labelled input-output data.
How it works: Model learns the relationship between features and known target variables.
Main tasks: Classification and regression.
Applications: Spam detection, medical diagnosis, and house-price prediction.
Advantages: Effective for prediction when sufficient labelled data is available.
Limitations: Requires labelled training data, which can be costly and time-consuming to obtain.
3. Unsupervised Learning
Key Sub-topics
Definition: Learning from unlabelled data without predefined target outputs.
How it works: Identifies patterns, relationships, or structures within datasets.
Main techniques: Clustering and dimensionality reduction.
Applications: Customer segmentation, anomaly detection, and market analysis.
Advantages: Can discover previously unknown patterns without labelled data.
Limitations: Results can be difficult to interpret and evaluate.
4. Reinforcement Learning
Key Sub-topics
Definition: Learning through interaction between an agent and its environment.
How it works: The agent takes actions and receives rewards or penalties.
Key concepts: Agent, environment, state, action, reward, and policy.
Applications: Robotics, autonomous systems, and game playing.
Advantages: Suitable for sequential decision-making and adaptive behaviour.
Limitations: Training can require substantial time, data, and computational resources.
5. Conclusion
Summarize the fundamental differences among the three paradigms.
Supervised learning predicts known outcomes, unsupervised learning discovers hidden patterns, and reinforcement learning learns optimal actions through feedback.
Conclude that selecting the appropriate paradigm depends on the nature of the problem, available data, and desired outcome."""
        },
        {
            "baseline_prompt": """I need to complete a comparison table for my university Software Engineering assignment comparing monolithic and microservices architectures. Can you create a table for me that compares them based on key factors like scalability, deployment complexity, fault isolation, and development speed? Make sure it is formatted clearly with explanations for each point so I can copy it into my assignment report.""",
            "baseline_output": """Below is a clear comparison table suitable for a university Software Engineering report.
Factor | Monolithic Architecture | Microservices Architecture
Structure | The application is built as a single integrated unit containing most or all major components. | The application is divided into small, independent services, each responsible for a specific function.
Scalability | Scaling can be less efficient because the entire application may need to be scaled, even if only one component needs additional resources. | Services can be scaled independently, allowing resources to be allocated where they are most needed.
Deployment Complexity | Relatively simple because the application is usually deployed as a single unit. | More complex because multiple services must be deployed, configured, monitored, and coordinated.
Fault Isolation | A failure in one component can potentially affect the entire application. | Failures can often be isolated to individual services, allowing other services to continue operating.
Development Speed | Often faster for small projects because developers work within one codebase and there is less infrastructure to manage. | Can be slower initially because teams must design service boundaries and manage communication between services, although development can become faster for large teams over time.
Maintenance | Easy to manage when small, but maintenance can become difficult as the codebase grows. | Individual services can be modified independently, making large systems easier to maintain when services are well designed.
Technology Flexibility | Usually uses a common technology stack across the application. | Different services can potentially use different technologies depending on their requirements.
Best Suited For | Small to medium-sized applications with relatively simple requirements. | Large, complex applications requiring independent scaling, deployment, and development by multiple teams.
Summary: Monolithic architecture generally offers simplicity and easier deployment, while microservices provide greater scalability, fault isolation, and flexibility at the cost of increased operational complexity.""",
            "optimized_prompt": """For a university Software Engineering assignment, generate a Markdown comparison table between Monolithic and Microservices architectures. Include:
Comparison across 4 key criteria (Scalability, Deployment Complexity, Fault Isolation, Development Speed).
Concise comparative descriptions (max 15 words per table cell).""",
            "optimized_output": """Criterion | Monolithic Architecture | Microservices Architecture
Scalability | Entire application must scale, potentially wasting resources. | Individual services scale independently according to demand.
Deployment Complexity | Simple deployment because the application operates as one unit. | More complex deployment requiring management of multiple independent services.
Fault Isolation | Failure in one component can affect the entire application. | Service failures can often remain isolated from other services.
Development Speed | Faster initially due to simpler development and unified codebase. | Initial development may be slower due to distributed-system complexity."""
        },
        {
            "baseline_prompt": """I am writing a case study analysis for my university Macroeconomics course about how tech companies respond to rising inflation rates. Could you please write a 200-word analysis paragraph summarizing the key challenge, explaining how inflation impacts operational costs, and proposing two strategic business solutions? Make sure it reads academically for submission.""",
            "baseline_output": """Case Study Analysis: Technology Companies and Rising Inflation
Rising inflation presents a significant challenge for technology companies because it increases operating costs while creating uncertainty about consumer demand and investment decisions. A key challenge is maintaining profitability without reducing competitiveness in a market where customers may become more price-sensitive. Inflation can increase operational costs through higher employee wages, office rents, cloud-computing services, energy prices, hardware components, transportation, and other business inputs. Technology firms may also face increased financing costs when central banks raise interest rates to control inflation, making investment in research, expansion, and infrastructure more expensive. If companies pass all cost increases to customers through higher prices, they risk losing demand or market share.
Two strategic solutions can help firms manage these pressures. First, companies can implement cost-efficiency measures, such as automating routine processes, optimizing cloud-resource usage, renegotiating supplier contracts, and prioritizing high-return investments. These measures can reduce unnecessary expenditure while maintaining product quality. Second, firms can adopt a strategic pricing and product approach, including carefully targeted price adjustments, tiered subscription plans, and greater emphasis on products or services with strong customer value. This allows companies to recover some increased costs without applying uniform price increases across all customers.
Overall, successful inflation management requires balancing cost control, pricing decisions, innovation, and long-term competitiveness.""",
            "optimized_prompt": """For a Macroeconomics case study assignment, write a 200-word corporate analysis paragraph addressing:
Statement of the primary inflation challenge facing tech firms.
Explanation of operational cost impacts.
Proposal of two strategic economic mitigation steps.""",
            "optimized_output": """Corporate Analysis: Inflation and Technology Firms
Rising inflation creates a significant challenge for technology firms by increasing operating expenses while potentially weakening consumer demand and profit margins. The primary challenge is maintaining profitability and competitiveness when the costs of labour, technology infrastructure, and business inputs are rising. Inflation affects operational costs through higher employee wages, office rents, energy prices, cloud-computing services, hardware, and supplier charges. In addition, central banks may respond to persistent inflation by raising interest rates, increasing borrowing costs for firms and making investment in research, expansion, and new infrastructure more expensive. If technology companies transfer these higher costs directly to customers through price increases, they may experience reduced demand or loss of market share.
Two strategic economic mitigation measures can help firms respond effectively. First, companies should strengthen cost efficiency by automating routine activities, optimizing cloud and energy consumption, renegotiating supplier contracts, and prioritizing investments with strong expected returns. Second, firms should adopt flexible pricing strategies, such as carefully targeted price increases, tiered subscription models, or differentiated product packages. These approaches can help recover higher costs while preserving affordability for price-sensitive customers. Overall, technology firms should combine disciplined cost management with carefully designed pricing strategies. This balanced approach can protect profit margins while maintaining customer value and supporting long-term competitiveness during periods of elevated inflation."""
        },
        {
            "baseline_prompt": """I am working on an assignment for my university Research Methods course where I need to argue why qualitative research methods are essential for studying human behavior. Please write a compelling academic paragraph of about 150 words that presents a strong claim, supports it with logical reasoning, and addresses a common counter-argument about quantitative objectivity.""",
            "baseline_output": """Importance of Qualitative Research in Studying Human Behavior
Qualitative research methods are essential for studying human behavior because they provide insight into the meanings, experiences, motivations, and social contexts that cannot always be adequately represented through numerical data. Human behavior is shaped by personal beliefs, cultural backgrounds, relationships, and situational factors; therefore, understanding these influences often requires methods such as interviews, observations, and focus groups that allow participants to describe their experiences in their own words. Although quantitative research is often considered more objective because it relies on standardized measurements and statistical analysis, numerical data alone may overlook the reasons behind people's actions or the complexity of their lived experiences. Critics may argue that qualitative research is subjective and therefore less reliable. However, researchers can strengthen qualitative credibility through systematic data collection, transparent analytical procedures, participant validation, and triangulation. Rather than competing with quantitative approaches, qualitative research complements them by explaining the meanings and processes underlying measurable patterns. Consequently, qualitative methods are indispensable for developing a deeper and more context-sensitive understanding of human behavior.""",
            "optimized_prompt": """For a university Research Methods assignment, write a 150-word argumentative paragraph favoring qualitative research for human behavior studies. Include:
A clear central topic claim.
Supporting logical reasoning and justification.
A concise counter-argument rebuttal regarding quantitative objectivity.""",
            "optimized_output": """Qualitative research is essential for studying human behavior because it reveals the meanings, experiences, motivations, and social contexts that numerical measurements alone may not capture. Human behavior is complex and influenced by factors such as culture, personal beliefs, relationships, and individual experiences; therefore, methods such as interviews, observations, and focus groups can provide detailed insights into why people behave in particular ways. Qualitative approaches also allow researchers to explore unexpected themes and perspectives that may not be identified through predetermined survey questions. Although quantitative research is often regarded as more objective because it uses standardized measurements and statistical analysis, objectivity does not necessarily mean complete understanding. Quantitative methods can identify patterns and relationships but may provide limited insight into the reasons and experiences underlying those patterns. Furthermore, qualitative research can maintain credibility through systematic procedures, transparent analysis, and triangulation. Therefore, qualitative research should be considered an essential approach for understanding human behavior, particularly when the research aims to explore complex experiences and social meanings."""
        },
    ],
    "Exam Preparation": [
        {
            "baseline_prompt": """I have an upcoming exam for my university Database Management Systems course and I need some practice questions to prepare. Can you please generate 5  practice multiple-choice questions for me focusing on SQL normalization (1NF, 2NF, and 3NF)? Please include 4 options for each question, clearly mark the correct answer, and provide a short explanation for each answer so I can study well for my test tomorrow.""",
            "baseline_output": """DBMS Normalization Practice MCQs
1. First Normal Form (1NF)
Which of the following is a requirement of First Normal Form (1NF)?
A. No partial dependencies
B. No transitive dependencies
C. Each attribute contains only atomic (single) values
D. Every non-key attribute depends on the primary key
Correct Answer: C
Explanation: 1NF requires each field to contain a single, indivisible value and does not allow repeating groups or multi-valued attributes.
2. Second Normal Form (2NF)
A relation is in 2NF if it is already in 1NF and:
A. It has no foreign keys
B. It has no partial dependency on a candidate key
C. It has no transitive dependencies
D. Every attribute is a primary key
Correct Answer: B
Explanation: 2NF eliminates partial dependencies, meaning every non-key attribute must depend on the entire candidate key, not just part of a composite key.
3. Third Normal Form (3NF)
Which type of dependency does 3NF primarily eliminate?
A. Functional dependency
B. Partial dependency
C. Transitive dependency
D. Multivalued dependency
Correct Answer: C
Explanation: 3NF eliminates transitive dependencies, where a non-key attribute depends on another non-key attribute rather than directly on the key.
4. Identifying 2NF
Consider the relation:
ENROLLMENT(Student_ID, Course_ID, Student_Name, Course_Name, Grade)
The primary key is (Student_ID, Course_ID). Which attribute creates a partial dependency?
A. Grade
B. Course_ID
C. Student_Name
D. Student_ID
Correct Answer: C
Explanation: Student_Name depends only on Student_ID, which is part of the composite key, so it creates a partial dependency and violates 2NF.
5. Identifying 3NF
Consider the relation:
STUDENT(Student_ID, Student_Name, Department_ID, Department_Name)
Given that Student_ID → Department_ID and Department_ID → Department_Name, what normalization problem exists?
A. Violation of 1NF
B. Partial dependency
C. Transitive dependency
D. Multivalued dependency
Correct Answer: C
Explanation: Department_Name depends on Department_ID, which depends on Student_ID, creating a transitive dependency that violates 3NF.""",
            "optimized_prompt": """For university DBMS exam prep, generate 5 practice MCQs on database normalization (1NF, 2NF, 3NF). Ensure the output includes:
4 distinct options per question.
The clearly indicated correct answer.
A brief explanation for each answer.""",
            "optimized_output": """DBMS Normalization — Practice MCQs
1. What is the main requirement of First Normal Form (1NF)?
A. Eliminate transitive dependencies
B. Eliminate partial dependencies
C. Ensure all attributes contain atomic values
D. Remove all foreign keys
Correct Answer: C
Explanation: A relation is in 1NF when each attribute contains a single, indivisible value and there are no repeating groups.
2. A relation is in Second Normal Form (2NF) when it is in 1NF and:
A. It has no transitive dependencies
B. It has no partial dependencies
C. All attributes are multivalued
D. It has no candidate keys
Correct Answer: B
Explanation: 2NF eliminates partial dependencies, where a non-key attribute depends on only part of a composite primary key.
3. Which dependency must be removed to achieve Third Normal Form (3NF)?
A. Functional dependency
B. Partial dependency
C. Transitive dependency
D. Candidate-key dependency
Correct Answer: C
Explanation: 3NF requires that non-key attributes do not depend on other non-key attributes through a transitive dependency.
4. Consider the relation ENROLLMENT(Student_ID, Course_ID, Student_Name, Grade) with primary key (Student_ID, Course_ID). If Student_ID → Student_Name, which normal form is violated?
A. 1NF
B. 2NF
C. 3NF
D. None
Correct Answer: B
Explanation: Student_Name depends only on part of the composite key (Student_ID), creating a partial dependency and violating 2NF.
5. Consider STUDENT(Student_ID, Student_Name, Department_ID, Department_Name). If Student_ID → Department_ID and Department_ID → Department_Name, what problem exists?
A. Repeating group
B. Partial dependency
C. Transitive dependency
D. Atomicity violation
Correct Answer: C
Explanation: Department_Name indirectly depends on Student_ID through Department_ID, creating a transitive dependency and violating 3NF."""
        },
        {
            "baseline_prompt": """I am studying for my university Operating Systems mid-term exam and I want to practice answering conceptual short questions. Could you please generate 3 short-answer exam questions about CPU scheduling algorithms like Round Robin and SJF? Please provide a concise standard answer for each question so I can grade myself after attempting them.""",
            "baseline_output": """Question 1 — Round Robin
What is the Round Robin (RR) CPU scheduling algorithm, and what is the role of the time quantum?
Standard Answer: Round Robin is a preemptive CPU scheduling algorithm in which each process is given a fixed time interval called a time quantum. When the quantum expires, the running process is preempted and moved to the end of the ready queue, allowing the next process to execute. A smaller quantum generally improves responsiveness but increases context-switching overhead.
Question 2 — Shortest Job First (SJF)
What is Shortest Job First (SJF) scheduling, and what is its main advantage?
Standard Answer: SJF selects the process with the shortest expected CPU burst time for execution. It can be either non-preemptive or related to the preemptive Shortest Remaining Time First (SRTF) approach. Its main advantage is that, when burst times are known accurately, SJF generally provides the minimum average waiting time among scheduling algorithms.
Question 3 — Comparing RR and SJF
State one major difference between Round Robin and SJF scheduling.
Standard Answer: Round Robin is preemptive and designed to provide fair CPU access and good responsiveness, giving each process a fixed time quantum. SJF selects the process with the shortest CPU burst and focuses primarily on minimizing average waiting time. Thus, RR is commonly suitable for time-sharing systems, while SJF is useful when CPU burst times can be estimated accurately.""",
            "optimized_prompt": """For an Operating Systems exam review, generate 3 short-answer theoretical questions on CPU scheduling (SJF, Round Robin, FCFS). Ensure the output includes:
Clear conceptual questions.
Concise model answers (max 3 sentences each).""",
            "optimized_output": """Operating Systems — CPU Scheduling Review
1. Shortest Job First (SJF)
Question: What is the Shortest Job First (SJF) scheduling algorithm, and what is its main advantage?
Model Answer: SJF selects the process with the shortest expected CPU burst for execution. Its main advantage is that it generally minimizes the average waiting time when CPU burst lengths can be estimated accurately.
2. Round Robin (RR)
Question: How does Round Robin scheduling work, and why is the time quantum important?
Model Answer: Round Robin assigns each ready process a fixed time quantum and cycles through them in a circular queue. When the quantum expires, the running process is preempted and placed at the end of the queue, providing fair CPU access and good responsiveness.
3. First-Come, First-Served (FCFS)
Question: What is FCFS scheduling, and what is one major disadvantage of this algorithm?
Model Answer: FCFS executes processes in the order they arrive in the ready queue and is generally non-preemptive. Its major disadvantage is the convoy effect, where short processes may have to wait a long time behind a long-running process."""
        },
        {
            "baseline_prompt": """I need to practice mathematical proofs and time complexity derivations for my university Data Structures and Algorithms final exam. Can you give me 1 practice problem where I have to solve recurrences using the Master Theorem? Please state the problem clearly and then provide a step-by-step mathematical solution for each so I can double-check my steps.""",
            "baseline_output": """Practice Problem — Master Theorem
Problem
Give one recurrence similar to:
T(n) = 2T(n/2) + n
Ask me to determine its asymptotic time complexity using the Master Theorem.
Step-by-Step Solution
Solve the recurrence completely and clearly.
Step 1: Identify a, b, and f(n)
First write the standard Master Theorem form:
T(n) = aT(n/b) + f(n)
Then clearly identify:
a = ...
b = ...
f(n) = ...
Step 2: Calculate n^(log_b a)
Show the calculation step by step.
For example:
n^(log_2 2)
Since:
log_2 2 = 1
Therefore:
n^(log_2 2) = n
Step 3: Compare f(n) with n^(log_b a)
Clearly compare the two expressions and explain whether they are smaller, equal, or larger.
Then explicitly state which Master Theorem case applies:
Case 1
Case 2
or Case 3
Step 4: Apply the appropriate Master Theorem case
Show the formula for the selected case and substitute the values step by step.
Final Answer
Clearly state the final asymptotic complexity in a boxed format, for example:
T(n) = Θ(n log n)""",
            "optimized_prompt": """For an Algorithms exam, create 1 recurrence relation practice problem solved via the Master Theorem. Provide:
Explicit recurrence equations T(n).
Step-by-step mathematical solution derivations.
Final Big-O time complexity bounds.""",
            "optimized_output": """Algorithms Exam Practice Problem: Master Theorem
Practice Problem
Solve the following recurrence relation using the Master Theorem:
T(n) = 4 T(n/2) + n
Assume base case T(1) = Theta(1) and n is a power of 2.
Step-by-Step Solution Derivation
Step 1: Identify the Master Theorem Parameters
The general form for the Master Theorem recurrence is:
T(n) = a T(n/b) + f(n)
Matching T(n) = 4 T(n/2) + n against the general form yields:
a = 4: The number of subproblems generated at each recursive step (a >= 1).
b = 2: The factor by which the input size is reduced (b > 1).
f(n) = n: The work done outside the recursive calls (combining and dividing step).
Step 2: Compute the Critical Exponent n^(log_b a)
Calculate the watershed/critical function n^(log_b a):
log_b a = log_2 4 = 2
So, the critical boundary function is:
n^(log_b a) = n^2
Step 3: Compare f(n) with n^(log_b a)
We now compare f(n) = n against n^(log_b a) = n^2:
f(n) = n grows strictly slower than n^(log_b a) = n^2.
Specifically, f(n) = O(n^(2 - epsilon)) for any epsilon where 0 < epsilon <= 1.
Because f(n) is polynomially smaller than n^(log_b a), the work done at the leaves dominates the total execution time.
Step 4: Apply the Master Theorem (Case 1)
According to Case 1 of the Master Theorem: If f(n) = O(n^(log_b a - epsilon)) for some constant epsilon > 0, then T(n) = Theta(n^(log_b a))
Substituting our values:
T(n) = Theta(n^2)
Final Time Complexity Bound
The exact tight bound for the recurrence is:
T(n) = Theta(n^2)
In terms of upper bound:
T(n) = O(n^2)"""
        },
        {
            "baseline_prompt": """I have a Computer Networks exam coming up that includes practical scenario questions. Can you generate 2 realistic network troubleshooting scenarios involving IP routing and subnetting issues? Please describe the scenario problem and then give a structured bulleted solution explaining how to diagnose and resolve the network issue.""",
            "baseline_output": """Network Troubleshooting Scenario: VLSM Subnet Mask Mismatch & Incomplete Route Summarization
Scenario Description
An enterprise network connects Headquarters (Router-HQ) to a Remote Branch (Router-BR) via a point-to-point serial link (10.0.0.0/30).
Router-HQ LAN: 192.168.1.0/24 (Gateway: 192.168.1.1)
Router-BR WAN Interface: 10.0.0.2/30
Router-HQ WAN Interface: 10.0.0.1/30
To accommodate growth, the Branch network was divided into two subnets using Variable Length Subnet Masking (VLSM):
Engineering Dept (VLAN 10): 192.168.2.0/25 (Valid hosts: 192.168.2.1 - 192.168.2.126; Gateway: 192.168.2.1)
Operations Dept (VLAN 20): 192.168.2.128/25 (Valid hosts: 192.168.2.129 - 192.168.2.254; Gateway: 192.168.2.129)
Configuration Errors:
1. On Router-HQ, the administrator added a static route for the Branch using a /25 mask instead of summarizing the entire /24 block: ip route 192.168.2.0 255.255.255.128 10.0.0.2
2. On Router-BR, a junior technician configured the Operations interface (192.168.2.129) with a /24 subnet mask (255.255.255.0) instead of /25 (255.255.255.128).
Symptoms:
Engineering hosts (192.168.2.50) have full bi-directional connectivity with HQ hosts (192.168.1.100).
Operations hosts (192.168.2.150) can ping their local gateway (192.168.2.129), but cannot ping HQ hosts (192.168.1.100).
HQ hosts (192.168.1.100) receive "Destination Host Unreachable" when attempting to ping Operations hosts (192.168.2.150).
Diagnostic & Resolution Steps
Step 1: Analyze Inbound Routing Table at Router-HQ. Check the routing table on Router-HQ: show ip route. Observe the entry: S 192.168.2.0/25 [1/0] via 10.0.0.2. Diagnosis: Router-HQ only knows how to reach 192.168.2.0 through 192.168.2.127. When HQ host 192.168.1.100 sends a packet to Operations host 192.168.2.150, Router-HQ drops the traffic because it lacks a matching route for the 192.168.2.128/25 block.
Step 2: Inspect Interface Configuration on Router-BR. Check the interface settings on Router-BR: show ip interface brief; show running-config interface GigabitEthernet0/0/2. Observe that interface Gi0/0/2 (Operations) is configured as: ip address 192.168.2.129 255.255.255.0. Diagnosis: Because the mask is set to /24, Router-BR treats the range 192.168.2.0 - 192.168.2.255 as a single directly connected broadcast domain. This creates an overlapping route conflict with interface Gi0/0/1 (Engineering, 192.168.2.1/25), causing ARP and packet forwarding errors between internal VLANs on Router-BR.
Step 3: Execute Path and ARP Troubleshooting. From HQ Host (192.168.1.100), run a traceroute: tracert 192.168.2.150. Result: The trace fails at the first hop (Router-HQ, 192.168.1.1) because Router-HQ has no route to 192.168.2.150. From Operations Host (192.168.2.150), run a traceroute: tracert 192.168.1.100. Result: Packets reach Router-BR (192.168.2.129) but fail to return due to local interface subnet overlaps.
Step 4: Resolve Configuration Issues. Fix 1 (Router-HQ): Update the static route on Router-HQ to summarize both /25 subnets into a single /24 route: no ip route 192.168.2.0 255.255.255.128 10.0.0.2; ip route 192.168.2.0 255.255.255.0 10.0.0.2. Fix 2 (Router-BR): Correct the subnet mask on the Operations interface to /25: interface GigabitEthernet0/0/2; ip address 192.168.2.129 255.255.255.128.
Step 5: Verify End-to-End Resolution. Verify the routing table on Router-HQ contains 192.168.2.0/24 via 10.0.0.2. From Operations host (192.168.2.150), execute ping 192.168.1.100. From HQ host (192.168.1.100), execute ping 192.168.2.150 to confirm full bi-directional communication across all subnets.""",
            "optimized_prompt": """For a university Computer Networks exam, generate 1 scenario-based troubleshooting problems regarding IP subnetting. Ensure the output provides:
Problem scenario description.
Step-by-step diagnosis procedure.
Correct solution and network configuration fix.""",
            "optimized_output": """Scenario-Based Troubleshooting: IP Subnetting Mask Mismatch
Problem Scenario Description
An enterprise organization allocates the IP block 10.10.0.0/22 for its corporate campus. To support a growing Engineering department, the network architect assigned a /23 block (10.10.0.0/23) to the Engineering VLAN (VLAN 10).
Network Settings: Subnet Assigned: 10.10.0.0/23. Subnet Mask: 255.255.254.0. Default Gateway (Router Gi0/0.10): 10.10.0.1. Valid Host Range: 10.10.0.1 - 10.10.1.254.
A new workstation, ENG-PC2, is assigned IP address 10.10.1.100. During manual setup, a network intern configured the host with the following parameters: IP Address: 10.10.1.100. Subnet Mask: 255.255.255.0 (/24). Default Gateway: 10.10.0.1.
Reported Symptoms:
1. ENG-PC2 can successfully ping older Engineering workstations located in the 10.10.1.1 - 10.10.1.254 range (e.g., 10.10.1.50).
2. ENG-PC2 cannot ping workstations located in the 10.10.0.2 - 10.10.0.255 range (e.g., 10.10.0.45), despite them being in the same physical VLAN and switch.
3. ENG-PC2 cannot ping its Default Gateway (10.10.0.1) and has no connectivity to other VLANs or the internet.
Step-by-Step Diagnosis Procedure
Step 1: Analyze the Subnet Math & Local Range. Intended /23 Subnet: Network ID: 10.10.0.0. Subnet Mask: 255.255.254.0. Usable IPs: 10.10.0.1 through 10.10.1.254. Gateway (10.10.0.1) and Host (10.10.1.100) are in the same logical /23 subnet. Misconfigured /24 Subnet on Host: Network ID: 10.10.1.0. Subnet Mask: 255.255.255.0. Usable Local IPs: 10.10.1.1 through 10.10.1.254.
Step 2: Trace Host Routing Logic. When ENG-PC2 (10.10.1.100) attempts to send a packet to 10.10.0.45: it performs a bitwise AND operation using its configured mask (255.255.255.0) on the target IP. It determines that 10.10.0.45 belongs to network 10.10.0.0/24, different from its own local network (10.10.1.0/24). Because the destination is deemed "remote," ENG-PC2 decides it must forward the packet to its Default Gateway (10.10.0.1).
Step 3: Identify Default Gateway Unreachability. ENG-PC2 checks the Default Gateway IP (10.10.0.1) against its own network address (10.10.1.0/24). It discovers that 10.10.0.1 is also outside its local /24 subnet boundaries. Operating system TCP/IP stacks treat a default gateway outside the local subnet as an invalid off-link address, causing all off-network traffic to immediately fail.
Correct Solution & Network Configuration Fix
Solution: Host Operating System Fix (Static Assignment). Correct the Subnet Mask on ENG-PC2 to match the /23 prefix length. Windows Network Interface Settings: IP Address: 10.10.1.100. Subnet Mask: 255.255.254.0 (Changed from 255.255.255.0). Default Gateway: 10.10.0.1."""
        },
        {
            "baseline_prompt": """I am revising key definitions and concepts for my university Object-Oriented Programming exam tomorrow. Can you create 3 flashcard style revision prompts covering OOP core concepts like Encapsulation, Polymorphism, and Abstraction? Please present them with a front question and a clear back answer so I can quickly test my memory.""",
            "baseline_output": """Flashcard 1 — Encapsulation
Front: What is Encapsulation in OOP?
Back: Encapsulation means bundling data and the methods that operate on that data into a single class, while restricting direct access to the internal data.
Example: Use private variables and public getter/setter methods.
Flashcard 2 — Polymorphism
Front: What is Polymorphism in OOP?
Back: Polymorphism means "many forms." It allows the same method/interface to behave differently depending on the object using it.
Example: A draw() method can produce different results for Circle, Rectangle, and Triangle objects.
Flashcard 3 — Abstraction
Front: What is Abstraction in OOP?
Back: Abstraction means hiding unnecessary implementation details and showing only the essential features to the user.
Example: You can call car.start() without needing to know the internal engine operations.""",
            "optimized_prompt": """For an Object-Oriented Programming exam revision, create 3 study flashcard pairs (Question and Answer) covering core principles. Provide:
Clear front-side conceptual questions.
Concise back-side answer definitions (max 2 sentences each).""",
            "optimized_output": """Flashcard 1 — Encapsulation
Question: What is encapsulation in Object-Oriented Programming?
Answer: Encapsulation is the process of bundling data and methods together inside a class while controlling access to the object's internal data.
Flashcard 2 — Polymorphism
Question: What does polymorphism mean in OOP?
Answer: Polymorphism means "many forms," allowing the same method or interface to behave differently depending on the object using it.
Flashcard 3 — Abstraction
Question: What is abstraction in Object-Oriented Programming?
Answer: Abstraction means hiding unnecessary implementation details and exposing only the essential features of an object."""
        },
    ],
    "Programming Help": [
        {
            "baseline_prompt": """I am working on a lab assignment for my university Computer Science course and I am trying to write a Python code to calculate the factorial of a number using recursion. However, my program is throwing a maximum recursion depth exceeded error when I run it. Can you please look at my code, explain what is wrong with the logic, provide the corrected code, and show how the function calls resolve for factorial(4) so I can complete my lab report?
Code:
def factorial(n):
    return n * factorial(n - 1)
print(factorial(5))""",
            "baseline_output": """The problem is that your recursive function has no base case. It keeps calling factorial(n - 1) indefinitely, eventually reaching Python's recursion limit.
Corrected Python Code
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)
print(factorial(5))""",
            "optimized_prompt": """Debug this Python recursive factorial function for a CS lab assignment:
def factorial(n):
    return n * factorial(n - 1)
Provide the following:
1. Explanation of the logical bug causing the error.
2. Corrected code including base cases (n <= 1).
3. Brief call stack trace for factorial(4).""",
            "optimized_output": """120
3. Call Stack Trace for factorial(4)
The calls proceed downward:
factorial(4)
4 * factorial(3)
4 * (3 * factorial(2))
4 * (3 * (2 * factorial(1)))
At factorial(1), the base case returns 1. The results then resolve backward:
factorial(1) = 1
factorial(2) = 2 * 1 = 2
factorial(3) = 3 * 2 = 6
factorial(4) = 4 * 6 = 24
Final result: factorial(4) = 24"""
        },
        {
            "baseline_prompt": """While solving a programming problem where I need to find duplicate elements in an integer array. My current Python implementation uses nested loops and runs very slowly O(n^2) on large inputs. Can you help me refactor this code to make it run faster in O(n) time using a Hash Set? Please provide the refactored code and explain how the time complexity improves.
Code:
def find_duplicates(arr):
    dups = []
    for i in range(len(arr)):
        for j in range(i + 1, len(arr)):
            if arr[i] == arr[j] and arr[i] not in dups:
                dups.append(arr[i])
    return dups""",
            "baseline_output": """Your current solution compares many pairs of elements, which makes it O(n²). A hash set lets us check whether an element has already appeared in average O(1) time.
Refactored Code
def find_duplicates(arr):
    seen = set()
    duplicates = set()
    for num in arr:
        if num in seen:
            duplicates.add(num)
        else:
            seen.add(num)
    return list(duplicates)
How it works: For each element, check whether num is already in seen. If it is, the element is a duplicate, so add it to duplicates. Otherwise, add it to seen.
Time Complexity: Original approach uses nested loops: O(n^2). Hash-set approach processes each element once, with average O(1) lookup and insertion, giving O(n). Additional space complexity is O(n)."""    ,
            "optimized_prompt": """Refactor this O(n^2) Python duplicate detection function for a CS lab to achieve O(n) time complexity using a Hash Set:
def find_duplicates(arr):
    dups = []
    for i in range(len(arr)):
        for j in range(i + 1, len(arr)):
            if arr[i] == arr[j] and arr[i] not in dups:
                dups.append(arr[i])
    return dups
Address the following:
1. Optimized Python code using set operations.
2. Brief explanation of how time complexity improves from O(n^2) to O(n).""",
            "optimized_output": """Optimized Python Code
def find_duplicates(arr):
    seen = set()
    duplicates = set()
    for num in arr:
        if num in seen:
            duplicates.add(num)
        else:
            seen.add(num)
    return list(duplicates)
Complexity Improvement: The original implementation uses nested loops, giving time complexity O(n^2). The optimized version scans the array only once. Hash-set operations such as in and add have average time complexity O(1). Thus for n elements: O(n). Extra space: O(n)."""
        },
        {
            "baseline_prompt": """For my university Algorithms assignment, I need to convert an iterative Fibonacci sequence function in C++ into a recursive function. Could you please rewrite the code using recursion instead of a for loop? Make sure to include the corrected code, explain how base cases are handled, and state any performance considerations like stack overhead.
Code:
int fibonacci(int n) {
    int a = 0, b = 1, c;
    if (n == 0) return a;
    for (int i = 2; i <= n; i++) {
        c = a + b;
        a = b;
        b = c;
    }
    return b;
}""",
            "baseline_output": """Recursive Fibonacci in C++
The iterative version can be converted by defining the Fibonacci sequence recursively: F(n) = F(n-1) + F(n-2), with base cases F(0)=0 and F(1)=1.
int fibonacci(int n) {
    if (n == 0) return 0;
    if (n == 1) return 1;
    return fibonacci(n - 1) + fibonacci(n - 2);
}""",
            "optimized_prompt": """Convert this iterative C++ Fibonacci function into a recursive implementation for an Algorithms assignment:
int fibonacci(int n) {
    int a = 0, b = 1, c;
    if (n == 0) return a;
    for (int i = 2; i <= n; i++) {
        c = a + b;
        a = b;
        b = c;
    }
    return b;
}
Provide:
1. Equivalent recursive C++ code handling base cases (n = 0, n = 1).
2. Brief note on call stack overhead during execution.""",
            "optimized_output": """Recursive C++ Implementation
int fibonacci(int n) {
    if (n == 0) return 0;
    if (n == 1) return 1;
    return fibonacci(n - 1) + fibonacci(n - 2);
}
The base cases handle n = 0 and n = 1, preventing infinite recursion. For larger values, the function recursively calculates the two preceding Fibonacci numbers and adds them.
Call Stack Overhead: Each recursive call creates a new stack frame containing parameters and the return address. The maximum recursion depth is O(n), so the recursive implementation requires O(n) stack space and can cause significant stack overhead for large n. This straightforward version also has O(2^n) time complexity because it repeatedly recalculates the same values."""
        },
        {
            "baseline_prompt": """I am writing Java code for a university Software Testing assignment where I need to make an array average calculation function robust. Right now, passing an empty array or null input crashes the program with ArithmeticException or NullPointerException. Can you help me fix this function so it safely handles empty arrays and null pointers without crashing?
Code:
public double calculateAverage(int[] numbers) {
    int sum = 0;
    for (int num : numbers) {
        sum += num;
    }
    return (double) sum / numbers.length;
}""",
            "baseline_output": """The two problems are: numbers == null causes a NullPointerException in the enhanced for loop. Empty array causes numbers.length to be 0, which is undesirable for an average function.
Corrected Java Code
public double calculateAverage(int[] numbers) {
    if (numbers == null || numbers.length == 0) {
        return 0.0;
    }
    int sum = 0;
    for (int num : numbers) {
        sum += num;
    }
    return (double) sum / numbers.length;
}
How it works: numbers == null checks for a null reference before accessing the array. numbers.length == 0 prevents calculation on an empty array. For either invalid case, the method returns 0.0. Otherwise, it calculates the average normally.""",
            "optimized_prompt": """Add robust edge-case handling to this Java array average function for a Software Testing lab:
public double calculateAverage(int[] numbers) {
    int sum = 0;
    for (int num : numbers) {
        sum += num;
    }
    return (double) sum / numbers.length;
}
Provide:
1. Corrected Java code handling null array reference and empty array (length == 0).
2. Brief explanation of defensive programming checks added.""",
            "optimized_output": """Corrected Java Code
public double calculateAverage(int[] numbers) {
    if (numbers == null || numbers.length == 0) {
        return 0.0;
    }
    int sum = 0;
    for (int num : numbers) {
        sum += num;
    }
    return (double) sum / numbers.length;
}
Defensive Programming Checks: numbers == null prevents a NullPointerException when no array reference is provided. numbers.length == 0 prevents an average calculation on an empty array. Returning 0.0 provides a defined result for these edge cases instead of allowing invalid input to cause unexpected behavior. The checks occur before accessing or iterating over the array."""
        },
        {
            "baseline_prompt": """I am building a project for my university Web Engineering lab and I am having trouble fetching JSON data from an API. My function prints Promise { <pending> } instead of the actual data because I am not handling the async response properly. Can you please look at my JavaScript code, fix the asynchronous issue using async/await, and explain why it wasn't working initially?
Code:
function fetchUserData() {
    let response = fetch("https://api.example.com/users");
    console.log(response);
}""",
            "baseline_output": """The issue is that fetch() is asynchronous and immediately returns a Promise. Your original code logs that Promise before the HTTP request has finished.
Corrected JavaScript Using async/await
async function fetchUserData() {
    try {
        const response = await fetch("https://api.example.com/users");
        if (!response.ok) {
            throw new Error(`HTTP error: ${response.status}`);
        }
        const data = await response.json();
        console.log(data);
        return data;
    } catch (error) {
        console.error("Failed to fetch user data:", error);
    }
}
fetchUserData();
Why the Original Code Failed: fetch() returns a Promise, representing a future result. Using await pauses the async function until the Promise resolves, and response.json() is also asynchronous so it must be awaited too. The try...catch additionally handles network or HTTP-related errors.""",
            "optimized_prompt": """Debug this JavaScript API fetch function for a Web Engineering lab task:
function fetchUserData() {
    let response = fetch("https://api.example.com/users");
    console.log(response);
}
Provide:
1. Explanation of why logging unhandled Promise returns pending.
2. Corrected implementation utilizing async/await and .json().
3. Brief explanation of asynchronous execution flow.""",
            "optimized_output": """Why does it log Promise { <pending> }? fetch() is asynchronous and immediately returns a Promise representing the future HTTP response. The original code logs that Promise before the network request has completed.
Corrected Implementation
async function fetchUserData() {
    try {
        const response = await fetch("https://api.example.com/users");
        const data = await response.json();
        console.log(data);
        return data;
    } catch (error) {
        console.error("Error fetching user data:", error);
    }
}
fetchUserData();
Asynchronous Execution Flow: fetchUserData() starts executing and calls fetch(). await fetch() waits for the Promise to resolve without blocking the main thread. Once the HTTP response arrives, response.json() asynchronously parses the response body. console.log(data) then displays the actual API data instead of the pending Promise."""
        },
    ],
    "Concept Learning": [
        {
            "baseline_prompt": """I am taking a university Machine Learning course and I need help understanding a core concept for my studies. Can you please explain what overfitting means in machine learning? Please define what it is, explain the main causes behind why it happens in models, give one real-world example to illustrate the concept clearly, and describe three standard techniques used to prevent it so that I can understand it thoroughly for my course.""",
            "baseline_output": """Overfitting in Machine Learning
Overfitting occurs when a machine learning model learns the training data too closely, including its noise and random patterns, instead of learning general patterns that apply to new data. As a result, the model performs very well on training data but poorly on unseen or test data.
Main Causes: Excessive model complexity - a model with too many parameters or layers can memorize training examples rather than learn general relationships. Insufficient training data - a small dataset may not represent the wider population. Noisy or irrelevant features - the model may learn random variations that do not generalize.
Real-World Example: Suppose a model is trained to identify cats from photographs. If the training images mostly show cats indoors, the model might incorrectly learn that indoor backgrounds indicate a cat. It may perform extremely well on training images but fail when shown a cat outdoors.
Three Ways to Prevent Overfitting: Cross-validation - evaluate the model across multiple training and validation splits. Regularization - add a penalty for overly complex models, such as L1 and L2 regularization. Early stopping - stop training when validation performance stops improving.
In short: Overfitting means excellent performance on training data but poor generalization to unseen data.""",
            "optimized_prompt": """For a university Machine Learning course, explain the concept of overfitting by covering:
1. Definition of the concept.
2. Primary causes of overfitting.
3. One real-world example.
4. Three standard prevention techniques.""",
            "optimized_output": """Overfitting in Machine Learning
1. Definition: Overfitting occurs when a machine learning model learns the training data too closely, including noise and insignificant patterns, performing well on training data but poorly on unseen data.
2. Primary Causes: Excessive model complexity - models with too many parameters can memorize training examples. Insufficient training data - small or unrepresentative datasets make memorization easier. Noisy or irrelevant data - the model may learn random variations. Excessive training - too many iterations can cause increasing fit to training data.
3. Real-World Example: Consider a model designed to detect spam emails. If it memorizes specific words or phrases in the training emails, it may correctly classify those but incorrectly classify new spam messages using different wording.
4. Three Prevention Techniques: Cross-validation - evaluate the model on different subsets of data. Regularization - penalize model complexity using L1 or L2 regularization. Early stopping - stop training when validation performance stops improving.
Key idea: A well-generalized model should perform consistently well on both training and previously unseen data."""
        },
        {
            "baseline_prompt": """I want to know about a university Web Engineering course and I need help understanding a core concept for my studies. Can you please explain what a RESTful API means in web development? Please define what it is, explain the main architectural principles behind how it works, give one real-world example to illustrate the concept clearly, and describe three common HTTP methods used in REST APIs so that I can understand it thoroughly for my course.""",
            "baseline_output": """RESTful API in Web Development
1. Definition: A RESTful API is a web API that allows different software systems to communicate over HTTP using a set of architectural principles. It typically exposes resources through URLs and allows clients to perform operations using standard HTTP methods.
2. Main Architectural Principles: Client-server architecture - client and server are separated. Statelessness - each request contains all necessary information. Resource-based design - data represented as resources identified by URLs. Uniform interface - standard HTTP methods make APIs predictable. Cacheability - responses can indicate whether they may be cached.
3. Real-World Example: Consider an online shopping application. A REST API might provide /products/101 to represent a particular product.
4. Three Common HTTP Methods: GET retrieves a resource (GET /products/101). POST creates a new resource (POST /products). DELETE removes a resource (DELETE /products/101).
In summary: RESTful APIs provide a standardized, scalable way for clients and servers to exchange information using HTTP and resource-oriented operations.""",
            "optimized_prompt": """For a university Web Engineering course, explain the concept of RESTful APIs by covering:
1. Definition of RESTful APIs.
2. Core architectural principles.
3. One real-world example.
4. Three standard HTTP methods (GET, POST, PUT/DELETE) and their functions.""",
            "optimized_output": """RESTful APIs
1. Definition: A RESTful API follows the principles of REST to enable communication between clients and servers over HTTP, representing data as resources identified by URLs.
2. Core Architectural Principles: Client-server architecture, Statelessness, Resource-based design, Uniform interface, Cacheability.
3. Real-World Example: An online shopping system could provide /api/products/101 representing product 101, used to retrieve, create, update, or remove product data.
4. Standard HTTP Methods: GET retrieves existing data. POST creates a new resource. PUT updates or replaces an existing resource. DELETE removes an existing resource.
In summary, RESTful APIs provide a standardized and scalable approach for communication between web clients and servers through resources, URLs, and HTTP methods."""
        },
        {
            "baseline_prompt": """I am studying for my university Operating Systems module and I'm having trouble grasping Virtual Memory. Can you explain the concept of Virtual Memory and how paging works? Please define virtual memory, list two major benefits it offers to modern OSs, explain page tables briefly with a simple example, and define what a page fault is so I can grasp the concept properly.""",
            "baseline_output": """Virtual Memory and Paging
1. What is Virtual Memory? Virtual memory is a memory-management technique that allows an OS to give each process the illusion of having a large, continuous memory space, even when physical RAM is limited.
2. Two Major Benefits: Larger address space - programs can use more memory than available physical RAM. Process isolation and protection - each process has its own virtual address space.
3. How Paging and Page Tables Work: Paging divides virtual memory into fixed-size pages and physical memory into equally sized frames. A page table maps virtual pages to physical frames. Example: Virtual Page 0 -> Physical Frame 5, Virtual Page 1 -> Physical Frame 2. If a program accesses virtual page 1, the page table tells the CPU it is stored in physical frame 2.
4. What is a Page Fault? A page fault occurs when a process tries to access a virtual page not currently loaded in RAM. The OS pauses the process, retrieves the page from secondary storage, updates the page table, and resumes the process.
Key idea: Virtual page -> Page table -> Physical frame -> Actual data in RAM.""",
            "optimized_prompt": """For a university Operating Systems course, explain Virtual Memory and Paging covering:
1. Definition of Virtual Memory.
2. Two core benefits to modern operating systems.
3. How Page Tables map virtual addresses to physical memory.
4. Definition of a Page Fault.""",
            "optimized_output": """Virtual Memory and Paging
1. Definition: Virtual memory gives each process the appearance of a large, continuous memory space, even when physical RAM is limited, using address translation and secondary storage.
2. Two Core Benefits: Efficient memory utilization - programs can use more than available RAM. Memory protection and isolation - each process has its own virtual address space.
3. How Page Tables Work: Paging divides virtual memory into fixed-size pages and physical memory into equal frames. A page table maps each virtual page to its physical frame. Example: Virtual Page 1 -> Physical Frame 7. The address also contains an offset specifying the exact position.
4. Definition of a Page Fault: A page fault occurs when a process accesses a virtual page not currently present in RAM. The OS loads the page from secondary storage, updates the page table, and allows the process to continue."""
        },
        {
            "baseline_prompt": """I need to learn about database transactions for my university DBMS course. Can you give me a clear breakdown of the ACID properties? Please define what ACID stands for, explain each of the four individual properties in detail, provide a real-world banking example showing why ACID matters, and summarize why transaction integrity is critical for relational databases.""",
            "baseline_output": """ACID Properties in Database Transactions
ACID stands for Atomicity, Consistency, Isolation, Durability.
1. Atomicity: A transaction is treated as a single, indivisible unit. Either all operations succeed or none are permanently applied. Example: transferring $500 requires both withdrawal and deposit to succeed together.
2. Consistency: Ensures a transaction takes the database from one valid state to another, maintaining all defined rules and constraints.
3. Isolation: Ensures concurrent transactions do not improperly interfere with one another.
4. Durability: Once a transaction is committed, its changes remain stored even after a crash or power loss.
Banking Example: Transferring $500 from Account A to Account B requires atomicity to prevent partial transfer, consistency to preserve database rules, isolation to prevent interference from concurrent transactions, and durability to ensure the transfer remains recorded after a failure.
Why Transaction Integrity Matters: ACID properties are critical because relational databases often store financial and other important data. Without transaction integrity, failures or concurrent operations could produce missing, duplicated, or inconsistent data.""",
            "optimized_prompt": """For a DBMS course, explain the ACID properties in database systems. Address:
1. Meaning of the ACID acronym.
2. Explanation of each property (Atomicity, Consistency, Isolation, Durability).
3. One real-world application example (e.g., bank transfer).""",
            "optimized_output": """ACID Properties in Database Systems
1. Meaning of ACID: Atomicity, Consistency, Isolation, Durability.
2. Explanation of Each Property: Atomicity - a transaction is one complete unit; all operations succeed or none apply. Consistency - a transaction moves the database from one valid state to another. Isolation - concurrent transactions do not improperly interfere with each other. Durability - once committed, changes are permanently stored.
3. Real-World Example: Transferring $500 from Account A to Account B. Atomicity ensures both operations succeed or roll back together. Consistency preserves account balances and constraints. Isolation prevents incorrect intermediate results from simultaneous transactions. Durability ensures the transfer survives a system failure.
Thus, ACID properties are essential for maintaining accurate, reliable, and consistent data, particularly in systems such as banking."""
        },
        {
            "baseline_prompt": """I will be taking a university Cybersecurity course and I need help understanding asymmetric encryption. Can you please explain Public Key Cryptography? Make sure to explain the difference between public and private keys, describe how key pairs work together during encryption and decryption, provide a real-world scenario like HTTPS, and state two key advantages over symmetric encryption.""",
            "baseline_output": """Public Key Cryptography (Asymmetric Encryption)
Public Key Cryptography uses a mathematically related key pair: a public key and a private key.
1. Public vs. Private Keys: The public key can be openly distributed and used to encrypt information. The private key must be kept secret and is used to decrypt information.
2. How Key Pairs Work: To send a confidential message, Alice encrypts using Bob's public key; only Bob's private key can decrypt it.
3. Real-World Example: HTTPS. HTTPS uses public-key cryptography as part of TLS. A website presents a certificate containing its public-key information, helping the browser authenticate the server.
4. Two Key Advantages: No pre-shared secret needed - parties can establish secure communication without exchanging a secret key beforehand. Digital signatures - supports authentication and integrity.
Key distinction: Symmetric encryption uses one shared secret key, while asymmetric cryptography uses a public/private key pair.""",
            "optimized_prompt": """For a university Cybersecurity course, explain Public Key Cryptography covering:
1. Definition and key concept (Public vs. Private Key).
2. How key pairs perform encryption and decryption.
3. One practical application (e.g., HTTPS/TLS).
4. Two advantages over symmetric encryption.""",
            "optimized_output": """Public Key Cryptography
1. Definition and Key Concept: Uses two mathematically related keys - a Public Key (openly shared, used for encryption) and a Private Key (kept secret, used for decryption).
2. Encryption and Decryption: The sender encrypts a message using the recipient's public key; only the corresponding private key can decrypt it.
3. Practical Application: HTTPS/TLS uses public-key cryptography to authenticate servers and establish secure connections via certificates.
4. Two Advantages Over Symmetric Encryption: No pre-shared secret required. Digital signatures support authentication, integrity, and non-repudiation.
In summary: Symmetric encryption uses one shared secret key, while public-key cryptography uses a public/private key pair."""
        },
    ],
    "Research Paper Summarization": [
        {
            "baseline_prompt": """I am currently writing a literature review for my university research project and I need to summarize an academic paper. Can you please read the attached paper text and give me a clear summary of it? I need you to explain the core research problem the paper focuses on, the overall methodology the authors used, their main findings, and the limitations of the study so that I can properly reference it in my review.""",
            "baseline_output": """The paper is a 2024 Heliyon study on healthcare access among marginalized women in Bangladesh and the design of a Bangla 24/7 voice-bot service.
1. Core Research Problem: The paper addresses limited healthcare access experienced by marginalized women in Bangladesh, particularly for menstrual and gynecological health, identifying barriers including poverty, low literacy, limited awareness, cultural taboos, and hesitation to seek medical assistance.
2. Methodology: The researchers used a mixed-method, field-based approach with marginalized women in Bangladeshi slum communities, comparing with privileged women. They designed a Bangla-language 24/7 voice-bot prototype using speech recognition, fuzzy string matching, a dataset of 408 Bangla Q&A pairs, and text-to-speech. The prototype was evaluated using 100 test questions.
3. Main Findings: Substantial healthcare disparities exist between marginalized and privileged women due to poverty, low literacy, and cultural barriers. The voice-bot correctly answered 76 of 100 test questions, indicating potential but also significant limitations, especially matching queries with fewer than three overlapping words.
4. Limitations: The research focused on one urban slum (Korail), limiting generalizability. Other limitations include sample-size constraints, self-reporting bias, limited data-collection time, and the voice-bot's 76% accuracy being insufficient for highly reliable healthcare guidance. Privacy, consent, and regulatory concerns also remain for future deployment.""",
            "optimized_prompt": """For a university literature review, summarize the attached research paper text using bullet points covering:
1. Core research problem addressed.
2. Methodology used.
3. Key findings.
4. Study limitations.""",
            "optimized_output": """Core research problem: The paper investigates barriers to healthcare access among marginalized women in Bangladesh, particularly menstrual and gynecological healthcare, examining socioeconomic, cultural, and educational barriers, and whether technology (a 24/7 Bangla voice-bot) can improve access.
Methodology used: Field research and mixed-method analysis involving marginalized women in Bangladeshi slum areas, compared with privileged women. They designed and evaluated a 24/7 Bangla voice-bot prototype using 100 test questions.
Key findings: Marginalized women face significant healthcare barriers from poverty, low literacy, affordability, and cultural stigma. The voice-bot correctly answered 76 of 100 test questions, showing potential but also room for improvement. Technology can help reduce access barriers but cannot eliminate underlying socioeconomic barriers alone.
Study limitations: Research focused on one slum (Korail), limiting generalizability. Sample size, self-reporting bias, and limited data-collection time are noted. The voice-bot's 76% accuracy was not sufficiently reliable for all queries. Privacy, consent, regulation, and legal compliance remain concerns for future implementation."""
        },
        {
            "baseline_prompt": """I am currently writing a literature review for my university research project on Green AI and sustainable computing, and I need to summarize an academic paper. Can you please read the attached paper text and give me a clear summary of it? I need you to explain the core research problem the paper focuses on, the overall experimental methodology the authors used, their key quantitative findings, and the limitations of the study so that I can properly reference it in my review.""",
            "baseline_output": """This is the "Green AI" paper by Schwartz, Dodge, Smith, and Etzioni (2019).
1. Core research problem: The paper addresses the rapid growth in computational cost of deep-learning research (approximately 300,000x increase from 2012-2018, doubling every few months) and the resulting environmental, economic, and accessibility problems. It argues AI research over-emphasizes accuracy ("Red AI") and proposes "Green AI," treating efficiency as an important research outcome.
2. Methodology: Primarily a position paper with empirical analysis. The authors sampled 60 papers from ACL, NeurIPS, and CVPR to examine whether contributions focused on accuracy, efficiency, both, or other. They also analyzed computational costs of existing models using FPO (floating-point operations) as a hardware-independent proxy, comparing models like AlexNet, ResNet, ResNeXt, DPN, and SENet.
3. Key quantitative findings: 300,000x increase in training computation 2012-2018. 90% of ACL, 80% of NeurIPS, 75% of CVPR papers targeted accuracy; only 10-20% emphasized efficiency. BERT-large trained on 64 TPUs for 4 days; Grover cost ~$25,000 to train. A ~35% increase in FPO between ResNet and ResNeXt produced only 0.5% accuracy improvement, showing diminishing returns.
4. Limitations: FPO is not a direct carbon-emissions measurement and ignores memory consumption and implementation efficiency. The cost equation (E x D x H) is simplified. The 60-paper sample is limited. As a position paper, it does not experimentally prove real-world carbon reductions from Green AI practices.""",
            "optimized_prompt": """For a university literature review on Green AI, summarize the attached research paper text using bullet points covering:
1. Core research problem addressed.
2. Experimental methodology used.
3. Key quantitative findings.
4. Study limitations.""",
            "optimized_output": """Core research problem: Addresses the rapid increase in computational requirements for deep-learning research (~300,000x from 2012-2018) and resulting environmental/economic costs. Argues AI research prioritizes accuracy over efficiency ("Red AI") and proposes "Green AI," treating efficiency as an evaluation criterion.
Experimental methodology: A position paper supported by empirical analysis of 60 papers from ACL, NeurIPS, and CVPR, classified by whether they focused on accuracy, efficiency, both, or other. Existing models (AlexNet, ResNet, ResNeXt, DPN, SENet) were compared using FPO (floating-point operations) as a hardware-independent efficiency metric.
Key quantitative findings: 300,000x computation increase 2012-2018, doubling every few months. 90% ACL, 80% NeurIPS, 75% CVPR papers targeted accuracy; only 10-20% emphasized efficiency. BERT-large used 64 TPUs for 4 days; Grover cost ~$25,000. A ~35% FPO increase from ResNet to ResNeXt gave only 0.5% accuracy improvement, illustrating diminishing returns.
Study limitations: FPO doesn't directly measure carbon emissions or capture memory consumption; results can depend on implementation. The cost model (E x D x H) is simplified, ignoring factors like training epochs. The 60-paper sample shows a trend rather than a comprehensive analysis. As a position paper, it doesn't experimentally demonstrate actual carbon reductions."""
        },
        {
            "baseline_prompt": """I have to present a research paper breakdown for my university AI seminar class. Could you please read the provided paper text on Convolutional Neural Networks and give me a complete summary? I need to understand what gap in literature the authors are addressing, what neural network model architecture they proposed, what empirical benchmarks/datasets they evaluated on, and what weaknesses remain in their approach.""",
            "baseline_output": """This is a review article: "Convolutional Neural Network (CNN): The Architecture and Applications" by Ayeni (2022), not a paper proposing/validating a new architecture.
1. Literature gap: The paper reviews CNN architecture, evolution, concepts, and applications for digital images and computer vision, synthesizing existing knowledge rather than filling a narrow experimental gap.
2. Architecture discussed: No novel architecture proposed. It explains the standard CNN structure: Convolutional layer (learnable filters detecting patterns), ReLU layer (introduces non-linearity), Pooling layer (reduces spatial dimensions via max/average pooling), and Fully connected layer (maps features to classification output).
3. Benchmarks/datasets: No original experiments conducted. The paper discusses ImageNet in relation to AlexNet/ReLU history, and reviews prior studies using MRI, X-ray, CT scan, and mammogram datasets for medical-image applications, and NLP applications like sentiment analysis and spam detection - all from cited prior research, not original experiments.
4. Weaknesses: No novel architecture or original empirical validation. No systematic benchmark comparison table. Relies heavily on secondary/tutorial sources. Notes limitations of CNN components themselves: ReLU can cause "dead neurons," and pooling can discard useful information. Being a 2022 review, it doesn't cover later CNN developments."""    ,
            "optimized_prompt": """For an academic AI seminar summary, analyze the attached Computer Vision paper using bullet points covering:
1. Specific research gap addressed.
2. Proposed model architecture and methodology.
3. Evaluation datasets and benchmark metrics.
4. Identified limitations or weaknesses.""",
            "optimized_output": """This is a review article, "Convolutional Neural Network (CNN): The Architecture and Applications" by Ayeni (2022), not a paper proposing/validating a new model.
Specific research gap addressed: Consolidates understanding of CNN architecture, concepts, evolution, and applications in computer vision, rather than addressing a narrow algorithmic performance gap.
Proposed model architecture and methodology: No new architecture proposed; explains the conventional CNN structure (Convolution, ReLU, Pooling, Fully connected layer) and how each component contributes to hierarchical feature learning. Methodology is a literature-based review, not original experimentation.
Evaluation datasets and benchmark metrics: No original dataset or benchmark evaluation reported. ImageNet, MRI, X-ray, CT scan, and mammogram datasets are discussed only as examples from cited prior research, not experiments run by this paper's author.
Identified limitations or weaknesses: No novel model or original empirical validation; no systematic quantitative benchmark comparison; broad but largely descriptive coverage; heavy reliance on secondary sources; notes ReLU's "dead neuron" issue and pooling's information loss as known component limitations."""
        },
        {
            "baseline_prompt": """I am gathering papers for my university thesis literature survey on Natural Language Processing and token usage efficiency. Can you summarize the attached paper for me? Please tell me what main research questions the paper investigates, what LLM models or tokenizers were tested in their experiments, what the primary results show regarding token waste, and what recommendations the authors make for future research.""",
            "baseline_output": """This is the "LLMLingua" paper on compressing prompts for accelerated LLM inference.
1. Main research questions: Can prompts be substantially shortened without losing needed information? Can token-level compression reduce inference cost while maintaining reasoning and in-context learning? How can a small model identify important tokens for a larger black-box LLM?
2. Models/tokenizers tested: Target LLMs were GPT-3.5-Turbo-0301 and Claude-v1.3. Small compressor models were Alpaca-7B and GPT2-Alpaca. GPT-4 was used to test information recovery. Token counts used tiktoken with GPT-3.5-Turbo.
3. Results on token waste: On GSM8K, the method achieved ~6x-20x compression depending on constraints while roughly maintaining accuracy (79.02 vs 78.85 Exact Match at 1-shot). On BBH, ~3x-7x compression. ShareGPT saw ~9x acceleration and Arxiv-March23 ~3.3x, with high BERTScore retained. At 5x compression, ~4x computational savings were estimated; latency dropped from 8.6s to 1.3s at 10x compression (5.7x speedup); GSM8K inference cost fell from $5.2 to $0.5.
4. Recommendations: Develop better compression methods without sacrificing reasoning; improve preservation of token dependencies for multi-step reasoning; address distribution mismatch between compressor and target LLM; account for tokenizer differences; investigate adaptive compression ratios; study performance degradation at extreme compression (25x-30x)."""    ,
            "optimized_prompt": """For an academic NLP literature survey, summarize the attached paper text using bullet points covering:
1. Primary research questions investigated.
2. Experimental setup and models evaluated.
3. Key findings on token efficiency/waste.
4. Author-recommended future directions.""",
            "optimized_output": """Primary research questions: Can prompts be compressed substantially while preserving needed information? Can compression reduce inference cost without harming performance? How can dependencies between important tokens be preserved during compression, and how does compressor/target-LLM distribution mismatch affect quality?
Experimental setup and models evaluated: LLMLingua uses a Budget Controller, Iterative Token-Level Prompt Compression, and Distribution Alignment. Target LLMs: GPT-3.5-Turbo-0301, Claude-v1.3. Compressors: Alpaca-7B, GPT2-Alpaca. Evaluated on GSM8K, BBH, ShareGPT, and Arxiv-March23 using EM, BLEU, ROUGE, and BERTScore; tokens counted with tiktoken.
Key findings on token efficiency/waste: Achieved ~6x-20x compression on GSM8K with minimal accuracy loss; ~3x-7x on BBH; ~9x and ~3.3x acceleration on ShareGPT and Arxiv-March23 respectively. At 5x compression, ~4x computational savings; latency improved from 8.6s to 1.3s (5.7x speedup) at 10x; GSM8K cost dropped from $5.2 to $0.5. Performance degrades substantially beyond ~25x-30x compression.
Author-recommended future directions: Develop higher-compression techniques without sacrificing reasoning; better preserve token dependencies for multi-step reasoning; address compressor/target-LLM distribution mismatch; account for tokenizer differences; investigate adaptive compression levels; further study the performance-compression trade-off."""
        },
        {
            "baseline_prompt": """I need to synthesize an empirical software engineering paper to include in my Master's thesis background chapter. Can you read the provided paper text and extract the key information? I need a summary covering the software engineering problem being studied, the research design (such as survey, case study, or repository mining), the statistical results obtained, and any threats to validity mentioned by the authors.""",
            "baseline_output": """This is a paper on the code-refactoring capability of LLMs (StarCoder2) by Cordeiro, Noei, and Zou.
1. SE problem studied: Whether StarCoder2 can perform code refactoring as effectively as human developers, focusing on code-smell reduction, quality improvement, and prompt engineering, across four research questions comparing LLM vs. developer refactoring effectiveness.
2. Research design: Repository mining combined with controlled experimentation. Using the 20-MAD dataset (765 Apache projects), filtered to 30 Java projects with 5,194 refactoring commits, excluding projects in StarCoder2's training data. Tools: RefactoringMiner, DesigniteJava, Understand, and unit tests. Three prompting strategies tested: zero-shot, one-shot, chain-of-thought.
3. Statistical results: Developer refactorings reduced code smells by 24.27%; StarCoder2 reduced them by 44.36% (p=0.003, statistically significant). Unit-test pass rate was 28.36% at pass@1, rising to 57.15% at pass@5. One-shot prompting improved pass rate to 34.51% and code-smell reduction to 42.97%, both better than zero-shot. StarCoder2 excelled at systematic/repetitive refactorings; developers were stronger at complex architectural changes.
4. Threats to validity: Internal - hardware/software variability, LLM hallucination, random commit selection, single-commit analysis, possible training-data overlap. External - limited to 30 Java/Apache projects, may not generalize to other languages/LLMs. Construct - quality assessed via code smells, metrics, and test pass rates, which don't capture readability or performance fully."""    ,
            "optimized_prompt": """For a Master's thesis literature chapter, synthesize the attached Software Engineering paper using bullet points covering:
1. Core software engineering problem studied.
2. Research methodology and data collection design.
3. Key statistical results.
4. Noted threats to validity.""",
            "optimized_output": """Core software engineering problem studied: Investigates whether StarCoder2 can perform automated code refactoring effectively, reducing code smells and improving quality metrics while preserving functionality, compared against real developer refactorings, across four research questions.
Research methodology and data collection design: Repository mining plus controlled experimentation using the 20-MAD dataset, filtered to 30 open-source Java projects (5,194 refactoring commits), excluding projects overlapping with StarCoder2's training data. Tools: RefactoringMiner, DesigniteJava, Understand, unit tests. Three prompting strategies: zero-shot, one-shot, chain-of-thought.
Key statistical results: Developer refactoring reduced code smells by 24.27% vs. 44.36% for StarCoder2 (statistically significant, p=0.003). One-shot prompting achieved 34.51% unit-test pass rate and 42.97% code-smell reduction, both improvements over zero-shot. StarCoder2 excelled at systematic/repetitive refactoring; developers performed better on complex, context-dependent architectural changes.
Noted threats to validity: Internal - hardware/software variability, LLM hallucination, random commit sampling, single-commit analysis, potential training-data overlap. External - limited to 30 Apache/Java projects, may not generalize to other languages or LLMs. Construct - quality measured via code smells, metrics, and test pass rates, which don't fully capture readability or runtime performance."""
        },
    ],
}

results = []
for category, pair_list in data.items():
    for idx, p in enumerate(pair_list, start=1):
        b_in = count_tokens(p["baseline_prompt"])
        b_out = count_tokens(p["baseline_output"])
        o_in = count_tokens(p["optimized_prompt"])
        o_out = count_tokens(p["optimized_output"])

        b_total = b_in + b_out
        o_total = o_in + o_out

        input_waste = b_in - o_in
        output_diff = b_out - o_out
        total_saved = b_total - o_total
        pct_reduction = (total_saved / b_total) * 100 if b_total > 0 else 0

        results.append({
            "Category": category,
            "Pair #": idx,
            "Baseline Input": b_in,
            "Baseline Output": b_out,
            "Baseline Total": b_total,
            "Optimized Input": o_in,
            "Optimized Output": o_out,
            "Optimized Total": o_total,
            "Input Tokens Wasted": input_waste,
            "Output Token Diff": output_diff,
            "Total Tokens Saved": total_saved,
            "Net % Reduction": round(pct_reduction, 2)
        })

df = pd.DataFrame(results)
print(df.to_string(index=False))

summary = df.groupby("Category").agg({
    "Baseline Total": "mean",
    "Optimized Total": "mean",
    "Input Tokens Wasted": "mean",
    "Total Tokens Saved": "mean",
    "Net % Reduction": "mean"
}).round(2)
print("\n=== Category Average ===")
print(summary)

overall = df.agg({
    "Baseline Total": "mean",
    "Optimized Total": "mean",
    "Input Tokens Wasted": "mean",
    "Total Tokens Saved": "mean",
    "Net % Reduction": "mean"
}).round(2)
print("\n=== Overall Average (All Categories) ===")
print(overall)

df.to_csv("all_categories_results.csv", index=False)
summary.to_csv("all_categories_summary.csv")
print("\nSaved: all_categories_results.csv, all_categories_summary.csv")
# Out:
# ...
#                     Category  Pair #  Baseline Input  Baseline Output  Baseline Total  Optimized Input  Optimized Output  Optimized Total  Input Tokens Wasted  Output Token Diff  Total Tokens Saved  Net % Reduction
#           Assignment Writing       1              83              260             343               51               266              317                   32                 -6                  26             7.58
#           Assignment Writing       2              80              681             761               58               448              506                   22                233                 255            33.51
#           Assignment Writing       3              69              355             424               57               107              164                   12                248                 260            61.32
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
